# %% [markdown]
# # Resnet50 on webcam - tensorrt

# %% [markdown]
# ## Import libraries

# %%
import torch
import torchvision
import cv2
import numpy as np
import time
import tensorrt as trt
import pycuda.driver as cuda
import pycuda.autoinit
import matplotlib.pyplot as plt
import os
import skimage.transform as skt
from torch.onnx import OperatorExportTypes

# %% [markdown]
# ## Download model

# %%
model = torchvision.models.resnet50(weights=torchvision.models.ResNet50_Weights.DEFAULT)

# %% [markdown]
# ## Labels

# %%
# dict with ImageNet labels
with open('imagenet_labels.txt') as f:
    labels = eval(f.read())

# %% [markdown]
# ## Export model to ONNX

# %%
BATCH_SIZE=1
# BATCH_SIZE=32

# %%
onnx_file = f"resnet50_pytorch_BS{BATCH_SIZE}.onnx"
if not os.path.exists(onnx_file):
    dummy_input=torch.randn(BATCH_SIZE, 3, 224, 224)
    torch.onnx.export(model, dummy_input, onnx_file, verbose=False, input_names=["input"], output_names=["output"], operator_export_type=OperatorExportTypes.ONNX_ATEN_FALLBACK)
else:
    print(f"{onnx_file} file already exists")

# %% [markdown]
# ## Export model to TRT

# %%
USE_FP16 = True
target_dtype = np.float16 if USE_FP16 else np.float32

# %%
tensorrt_file = f"resnet50_engine_pytorch_BS{BATCH_SIZE}.trt"
if not os.path.exists(tensorrt_file):
    if USE_FP16:
        # !/usr/src/tensorrt/bin/trtexec --onnx=resnet50_pytorch_BS{BATCH_SIZE}.onnx --saveEngine=resnet50_engine_pytorch_BS{BATCH_SIZE}.trt  --explicitBatch --inputIOFormats=fp16:chw --outputIOFormats=fp16:chw --fp16
    else:
        # !/usr/src/tensorrt/bin/trtexec --onnx=resnet50_pytorch_BS{BATCH_SIZE}.onnx --saveEngine=resnet50_engine_pytorch_BS{BATCH_SIZE}.trt  --explicitBatch
else:
    print(f"{tensorrt_file} engine already exists")
# Out:
# resnet50_engine_pytorch_BS1.trt engine already exists

# %% [markdown]
# ## Export model to ENGINE

# %%
USE_FP16 = True
target_dtype = np.float16 if USE_FP16 else np.float32

# %%
tensorrt_file = f"resnet50_engine_pytorch_BS{BATCH_SIZE}.engine"
if not os.path.exists(tensorrt_file):
    if USE_FP16:
        # !/usr/src/tensorrt/bin/trtexec --onnx=resnet50_pytorch_BS{BATCH_SIZE}.onnx --saveEngine={tensorrt_file}  --explicitBatch --inputIOFormats=fp16:chw --outputIOFormats=fp16:chw --fp16
        # !/usr/src/tensorrt/bin/trtexec --onnx=../../tensorrt/resnet50_pytorch_BS1.onnx --saveEngine=resnet50_engine_pytorch_BS1.engine --explicitBatch --inputIOFormats=fp16:chw --outputIOFormats=fp16:chw --fp16
    else:
        # !/usr/src/tensorrt/bin/trtexec --onnx=resnet50_pytorch_BS{BATCH_SIZE}.onnx --saveEngine={tensorrt_file}  --explicitBatch
else:
    print(f"{tensorrt_file} engine already exists")
# Out:
# &&&& RUNNING TensorRT.trtexec [TensorRT v8403] # /usr/src/tensorrt/bin/trtexec --onnx=resnet50_pytorch_BS1.onnx --saveEngine=resnet50_engine_pytorch_BS1.engine --explicitBatch --inputIOFormats=fp16:chw --outputIOFormats=fp16:chw --fp16
# [11/30/2022-09:30:40] [W] --explicitBatch flag has been deprecated and has no effect!
# [11/30/2022-09:30:40] [W] Explicit batch dim is automatically enabled if input model is ONNX or if dynamic shapes are provided when the engine is built.
# [11/30/2022-09:30:40] [I] === Model Options ===
# [11/30/2022-09:30:40] [I] Format: ONNX
# [11/30/2022-09:30:40] [I] Model: resnet50_pytorch_BS1.onnx
# [11/30/2022-09:30:40] [I] Output:
# [11/30/2022-09:30:40] [I] === Build Options ===
# [11/30/2022-09:30:40] [I] Max batch: explicit batch
# [11/30/2022-09:30:40] [I] Memory Pools: workspace: default, dlaSRAM: default, dlaLocalDRAM: default, dlaGlobalDRAM: default
# [11/30/2022-09:30:40] [I] minTiming: 1
# [11/30/2022-09:30:40] [I] avgTiming: 8
# [11/30/2022-09:30:40] [I] Precision: FP32+FP16
# [11/30/2022-09:30:40] [I] LayerPrecisions:
# [11/30/2022-09:30:40] [I] Calibration:
# [11/30/2022-09:30:40] [I] Refit: Disabled
# [11/30/2022-09:30:40] [I] Sparsity: Disabled
# [11/30/2022-09:30:40] [I] Safe mode: Disabled
# [11/30/2022-09:30:40] [I] DirectIO mode: Disabled
# [11/30/2022-09:30:40] [I] Restricted mode: Disabled
# [11/30/2022-09:30:40] [I] Build only: Disabled
# [11/30/2022-09:30:40] [I] Save engine: resnet50_engine_pytorch_BS1.engine
# [11/30/2022-09:30:40] [I] Load engine:
# [11/30/2022-09:30:40] [I] Profiling verbosity: 0
# [11/30/2022-09:30:40] [I] Tactic sources: Using default tactic sources
# [11/30/2022-09:30:40] [I] timingCacheMode: local
# [11/30/2022-09:30:40] [I] timingCacheFile:
# [11/30/2022-09:30:40] [I] Input(s): fp16:chw
# [11/30/2022-09:30:40] [I] Output(s): fp16:chw
# [11/30/2022-09:30:40] [I] Input build shapes: model
# [11/30/2022-09:30:40] [I] Input calibration shapes: model
# [11/30/2022-09:30:40] [I] === System Options ===
# [11/30/2022-09:30:40] [I] Device: 0
# [11/30/2022-09:30:40] [I] DLACore:
# [11/30/2022-09:30:40] [I] Plugins:
# [11/30/2022-09:30:40] [I] === Inference Options ===
# [11/30/2022-09:30:40] [I] Batch: Explicit
# [11/30/2022-09:30:40] [I] Input inference shapes: model
# [11/30/2022-09:30:40] [I] Iterations: 10
# [11/30/2022-09:30:40] [I] Duration: 3s (+ 200ms warm up)
# [11/30/2022-09:30:40] [I] Sleep time: 0ms
# [11/30/2022-09:30:40] [I] Idle time: 0ms
# [11/30/2022-09:30:40] [I] Streams: 1
# [11/30/2022-09:30:40] [I] ExposeDMA: Disabled
# [11/30/2022-09:30:40] [I] Data transfers: Enabled
# [11/30/2022-09:30:40] [I] Spin-wait: Disabled
# [11/30/2022-09:30:40] [I] Multithreading: Disabled
# [11/30/2022-09:30:40] [I] CUDA Graph: Disabled
# [11/30/2022-09:30:40] [I] Separate profiling: Disabled
# [11/30/2022-09:30:40] [I] Time Deserialize: Disabled
# [11/30/2022-09:30:40] [I] Time Refit: Disabled
# [11/30/2022-09:30:40] [I] Inputs:
# [11/30/2022-09:30:40] [I] === Reporting Options ===
# [11/30/2022-09:30:40] [I] Verbose: Disabled
# [11/30/2022-09:30:40] [I] Averages: 10 inferences
# [11/30/2022-09:30:40] [I] Percentile: 99
# [11/30/2022-09:30:40] [I] Dump refittable layers:Disabled
# [11/30/2022-09:30:40] [I] Dump output: Disabled
# [11/30/2022-09:30:40] [I] Profile: Disabled
# [11/30/2022-09:30:40] [I] Export timing to JSON file:
# [11/30/2022-09:30:40] [I] Export output to JSON file:
# [11/30/2022-09:30:40] [I] Export profile to JSON file:
# [11/30/2022-09:30:40] [I]
# [11/30/2022-09:30:40] [I] === Device Information ===
# [11/30/2022-09:30:40] [I] Selected Device: Quadro T1000
# [11/30/2022-09:30:40] [I] Compute Capability: 7.5
# [11/30/2022-09:30:40] [I] SMs: 14
# [11/30/2022-09:30:40] [I] Compute Clock Rate: 1.53 GHz
# [11/30/2022-09:30:40] [I] Device Global Memory: 3914 MiB
# [11/30/2022-09:30:40] [I] Shared Memory per SM: 64 KiB
# [11/30/2022-09:30:40] [I] Memory Bus Width: 128 bits (ECC disabled)
# [11/30/2022-09:30:40] [I] Memory Clock Rate: 6.001 GHz
# [11/30/2022-09:30:40] [I]
# [11/30/2022-09:30:40] [I] TensorRT version: 8.4.3
# [11/30/2022-09:30:40] [I] [TRT] [MemUsageChange] Init CUDA: CPU +311, GPU +0, now: CPU 319, GPU 236 (MiB)
# [11/30/2022-09:30:42] [I] [TRT] [MemUsageChange] Init builder kernel library: CPU +207, GPU +68, now: CPU 545, GPU 304 (MiB)
# [11/30/2022-09:30:42] [I] Start parsing network model
# [11/30/2022-09:30:42] [I] [TRT] ----------------------------------------------------------------
# [11/30/2022-09:30:42] [I] [TRT] Input filename:   resnet50_pytorch_BS1.onnx
# [11/30/2022-09:30:42] [I] [TRT] ONNX IR version:  0.0.7
# [11/30/2022-09:30:42] [I] [TRT] Opset version:    14
# [11/30/2022-09:30:42] [I] [TRT] Producer name:    pytorch
# [11/30/2022-09:30:42] [I] [TRT] Producer version: 1.13.0
# [11/30/2022-09:30:42] [I] [TRT] Domain:
# [11/30/2022-09:30:42] [I] [TRT] Model version:    0
# [11/30/2022-09:30:42] [I] [TRT] Doc string:
# [11/30/2022-09:30:42] [I] [TRT] ----------------------------------------------------------------
# [11/30/2022-09:30:42] [I] Finish parsing network model
# [11/30/2022-09:30:43] [I] [TRT] [MemUsageChange] Init cuBLAS/cuBLASLt: CPU +518, GPU +226, now: CPU 1161, GPU 530 (MiB)
# [11/30/2022-09:30:43] [I] [TRT] [MemUsageChange] Init cuDNN: CPU +117, GPU +52, now: CPU 1278, GPU 582 (MiB)
# [11/30/2022-09:30:43] [I] [TRT] Local timing cache in use. Profiling results in this builder pass will not be stored.
# [11/30/2022-09:30:46] [W] [TRT] Weights [name=/conv1/Conv + /relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:46] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:46] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:46] [W] [TRT] Weights [name=/conv1/Conv + /relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:46] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:46] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:46] [W] [TRT] Weights [name=/conv1/Conv + /relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:46] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:46] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:46] [W] [TRT] Weights [name=/conv1/Conv + /relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:46] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:46] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:46] [W] [TRT] Weights [name=/conv1/Conv + /relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:46] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:46] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:46] [W] [TRT] Weights [name=/conv1/Conv + /relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:46] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:46] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:46] [W] [TRT] Weights [name=/conv1/Conv + /relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:46] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:46] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:46] [W] [TRT] Weights [name=/conv1/Conv + /relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:46] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:46] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:51] [W] [TRT] Weights [name=/layer1/layer1.0/conv1/Conv + /layer1/layer1.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:51] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:51] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:51] [W] [TRT] Weights [name=/layer1/layer1.0/conv1/Conv + /layer1/layer1.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:51] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:51] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:51] [W] [TRT] Weights [name=/layer1/layer1.0/conv1/Conv + /layer1/layer1.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:51] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:51] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:51] [W] [TRT] Weights [name=/layer1/layer1.0/conv1/Conv + /layer1/layer1.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:51] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:51] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:51] [W] [TRT] Weights [name=/layer1/layer1.0/conv1/Conv + /layer1/layer1.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:51] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:51] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:51] [W] [TRT] Weights [name=/layer1/layer1.0/conv1/Conv + /layer1/layer1.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:51] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:51] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:51] [W] [TRT] Weights [name=/layer1/layer1.0/conv1/Conv + /layer1/layer1.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:51] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:51] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:51] [W] [TRT] Weights [name=/layer1/layer1.0/conv1/Conv + /layer1/layer1.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:51] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:51] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:51] [W] [TRT] Weights [name=/layer1/layer1.0/conv1/Conv + /layer1/layer1.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:51] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:51] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:51] [W] [TRT] Weights [name=/layer1/layer1.0/conv1/Conv + /layer1/layer1.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:51] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:51] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:51] [W] [TRT] Weights [name=/layer1/layer1.0/conv1/Conv + /layer1/layer1.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:51] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:51] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:51] [W] [TRT] Weights [name=/layer1/layer1.0/conv1/Conv + /layer1/layer1.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:51] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:51] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:52] [W] [TRT] Weights [name=/layer1/layer1.0/conv2/Conv + /layer1/layer1.0/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:52] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:52] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:52] [W] [TRT] Weights [name=/layer1/layer1.0/conv2/Conv + /layer1/layer1.0/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:52] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:52] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:52] [W] [TRT] Weights [name=/layer1/layer1.0/conv2/Conv + /layer1/layer1.0/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:52] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:52] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:52] [W] [TRT] Weights [name=/layer1/layer1.0/conv2/Conv + /layer1/layer1.0/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:52] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:52] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:52] [W] [TRT] Weights [name=/layer1/layer1.0/conv2/Conv + /layer1/layer1.0/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:52] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:52] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:52] [W] [TRT] Weights [name=/layer1/layer1.0/conv2/Conv + /layer1/layer1.0/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:52] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:52] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:52] [W] [TRT] Weights [name=/layer1/layer1.0/conv2/Conv + /layer1/layer1.0/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:52] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:52] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:53] [W] [TRT] Weights [name=/layer1/layer1.0/downsample/downsample.0/Conv.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:53] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:53] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:53] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:53] [W] [TRT] Weights [name=/layer1/layer1.0/downsample/downsample.0/Conv.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:53] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:53] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:53] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:53] [W] [TRT] Weights [name=/layer1/layer1.0/downsample/downsample.0/Conv.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:53] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:53] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:53] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:53] [W] [TRT] Weights [name=/layer1/layer1.0/downsample/downsample.0/Conv.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:53] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:53] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:53] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:53] [W] [TRT] Weights [name=/layer1/layer1.0/downsample/downsample.0/Conv.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:53] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:53] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:53] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:53] [W] [TRT] Weights [name=/layer1/layer1.0/downsample/downsample.0/Conv.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:53] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:53] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:53] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:53] [W] [TRT] Weights [name=/layer1/layer1.0/downsample/downsample.0/Conv.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:53] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:53] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:53] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:53] [W] [TRT] Weights [name=/layer1/layer1.0/downsample/downsample.0/Conv.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:53] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:53] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:53] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:53] [W] [TRT] Weights [name=/layer1/layer1.0/downsample/downsample.0/Conv.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:53] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:53] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:53] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:53] [W] [TRT] Weights [name=/layer1/layer1.0/downsample/downsample.0/Conv.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:53] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:53] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:53] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:53] [W] [TRT] Weights [name=/layer1/layer1.0/downsample/downsample.0/Conv.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:53] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:53] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:53] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:53] [W] [TRT] Weights [name=/layer1/layer1.0/downsample/downsample.0/Conv.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:53] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:53] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:53] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.0/conv3/Conv + /layer1/layer1.0/Add + /layer1/layer1.0/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.0/conv3/Conv + /layer1/layer1.0/Add + /layer1/layer1.0/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.0/conv3/Conv + /layer1/layer1.0/Add + /layer1/layer1.0/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.0/conv3/Conv + /layer1/layer1.0/Add + /layer1/layer1.0/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.0/conv3/Conv + /layer1/layer1.0/Add + /layer1/layer1.0/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.0/conv3/Conv + /layer1/layer1.0/Add + /layer1/layer1.0/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.0/conv3/Conv + /layer1/layer1.0/Add + /layer1/layer1.0/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.0/conv3/Conv + /layer1/layer1.0/Add + /layer1/layer1.0/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.0/conv3/Conv + /layer1/layer1.0/Add + /layer1/layer1.0/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.0/conv3/Conv + /layer1/layer1.0/Add + /layer1/layer1.0/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.0/conv3/Conv + /layer1/layer1.0/Add + /layer1/layer1.0/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.1/conv1/Conv + /layer1/layer1.1/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.1/conv1/Conv + /layer1/layer1.1/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.1/conv1/Conv + /layer1/layer1.1/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:54] [W] [TRT] Weights [name=/layer1/layer1.1/conv1/Conv + /layer1/layer1.1/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:54] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:54] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:54] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv1/Conv + /layer1/layer1.1/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv1/Conv + /layer1/layer1.1/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv1/Conv + /layer1/layer1.1/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv1/Conv + /layer1/layer1.1/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv1/Conv + /layer1/layer1.1/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv1/Conv + /layer1/layer1.1/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv1/Conv + /layer1/layer1.1/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv1/Conv + /layer1/layer1.1/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv2/Conv + /layer1/layer1.1/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv2/Conv + /layer1/layer1.1/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv2/Conv + /layer1/layer1.1/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv2/Conv + /layer1/layer1.1/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv3/Conv + /layer1/layer1.1/Add + /layer1/layer1.1/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv3/Conv + /layer1/layer1.1/Add + /layer1/layer1.1/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv3/Conv + /layer1/layer1.1/Add + /layer1/layer1.1/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv3/Conv + /layer1/layer1.1/Add + /layer1/layer1.1/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.1/conv3/Conv + /layer1/layer1.1/Add + /layer1/layer1.1/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv1/Conv + /layer1/layer1.2/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv1/Conv + /layer1/layer1.2/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv1/Conv + /layer1/layer1.2/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv1/Conv + /layer1/layer1.2/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv1/Conv + /layer1/layer1.2/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv1/Conv + /layer1/layer1.2/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv2/Conv + /layer1/layer1.2/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv2/Conv + /layer1/layer1.2/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv2/Conv + /layer1/layer1.2/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv2/Conv + /layer1/layer1.2/relu_1/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv3/Conv + /layer1/layer1.2/Add + /layer1/layer1.2/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv3/Conv + /layer1/layer1.2/Add + /layer1/layer1.2/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv3/Conv + /layer1/layer1.2/Add + /layer1/layer1.2/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv3/Conv + /layer1/layer1.2/Add + /layer1/layer1.2/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:55] [W] [TRT] Weights [name=/layer1/layer1.2/conv3/Conv + /layer1/layer1.2/Add + /layer1/layer1.2/relu_2/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:55] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:55] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:30:55] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:56] [W] [TRT] Weights [name=/layer2/layer2.0/conv1/Conv + /layer2/layer2.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:56] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:56] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:56] [W] [TRT] Weights [name=/layer2/layer2.0/conv1/Conv + /layer2/layer2.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:56] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:56] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:30:56] [W] [TRT] Weights [name=/layer2/layer2.0/conv1/Conv + /layer2/layer2.0/relu/Relu.weight] had the following issues when converted to FP16:
# [11/30/2022-09:30:56] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:30:56] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# ...
# [11/30/2022-09:31:38] [W] [TRT] Weights [name=/fc/Gemm.weight] had the following issues when converted to FP16:
# [11/30/2022-09:31:38] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:31:38] [W] [TRT]  - Values less than smallest positive FP16 Subnormal value detected. Converting to FP16 minimum subnormalized value.
# [11/30/2022-09:31:38] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:31:38] [W] [TRT] Weights [name=/fc/Gemm.bias] had the following issues when converted to FP16:
# [11/30/2022-09:31:38] [W] [TRT]  - Subnormal FP16 values detected.
# [11/30/2022-09:31:38] [W] [TRT] If this is not the desired behavior, please modify the weights or retrain with regularization to reduce the magnitude of the weights.
# [11/30/2022-09:31:38] [I] [TRT] Total Host Persistent Memory: 135296
# [11/30/2022-09:31:38] [I] [TRT] Total Device Persistent Memory: 292864
# [11/30/2022-09:31:38] [I] [TRT] Total Scratch Memory: 0
# [11/30/2022-09:31:38] [I] [TRT] [MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 0 MiB, GPU 0 MiB
# [11/30/2022-09:31:38] [I] [TRT] [BlockAssignment] Algorithm ShiftNTopDown took 2.22605ms to assign 3 blocks to 57 nodes requiring 3612672 bytes.
# [11/30/2022-09:31:38] [I] [TRT] Total Activation Memory: 3612672
# [11/30/2022-09:31:38] [I] [TRT] [MemUsageChange] TensorRT-managed allocation in building engine: CPU +0, GPU +0, now: CPU 0, GPU 0 (MiB)
# [11/30/2022-09:31:38] [W] [TRT] The getMaxBatchSize() function should not be used with an engine built from a network created with NetworkDefinitionCreationFlag::kEXPLICIT_BATCH flag. This function will always return 1.
# [11/30/2022-09:31:38] [W] [TRT] The getMaxBatchSize() function should not be used with an engine built from a network created with NetworkDefinitionCreationFlag::kEXPLICIT_BATCH flag. This function will always return 1.
# [11/30/2022-09:31:38] [I] Engine built in 58.6728 sec.
# [11/30/2022-09:31:38] [I] [TRT] [MemUsageChange] Init CUDA: CPU +0, GPU +0, now: CPU 1536, GPU 716 (MiB)
# [11/30/2022-09:31:38] [I] [TRT] Loaded engine size: 49 MiB
# [11/30/2022-09:31:38] [I] [TRT] [MemUsageChange] TensorRT-managed allocation in engine deserialization: CPU +0, GPU +0, now: CPU 0, GPU 0 (MiB)
# [11/30/2022-09:31:38] [I] Engine deserialized in 0.0119108 sec.
# [11/30/2022-09:31:38] [I] [TRT] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +0, now: CPU 0, GPU 0 (MiB)
# [11/30/2022-09:31:38] [I] Using random values for input input.1
# [11/30/2022-09:31:38] [I] Created input binding for input.1 with dimensions 1x3x224x224
# [11/30/2022-09:31:38] [I] Using random values for output 495
# [11/30/2022-09:31:38] [I] Created output binding for 495 with dimensions 1x1000
# [11/30/2022-09:31:38] [I] Starting inference
# [11/30/2022-09:31:41] [I] Warmup completed 65 queries over 200 ms
# [11/30/2022-09:31:41] [I] Timing trace has 963 queries over 3.0072 s
# [11/30/2022-09:31:41] [I]
# [11/30/2022-09:31:41] [I] === Trace details ===
# [11/30/2022-09:31:41] [I] Trace averages of 10 runs:
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11388 ms - Host latency: 3.17873 ms (enqueue 0.214555 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11229 ms - Host latency: 3.17828 ms (enqueue 0.233499 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11312 ms - Host latency: 3.17722 ms (enqueue 0.229105 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10939 ms - Host latency: 3.17389 ms (enqueue 0.231784 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11024 ms - Host latency: 3.17503 ms (enqueue 0.234164 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1092 ms - Host latency: 3.17466 ms (enqueue 0.235284 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1146 ms - Host latency: 3.17949 ms (enqueue 0.216678 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10946 ms - Host latency: 3.17376 ms (enqueue 0.211252 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10999 ms - Host latency: 3.1743 ms (enqueue 0.221744 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1102 ms - Host latency: 3.17769 ms (enqueue 0.22547 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1102 ms - Host latency: 3.17526 ms (enqueue 0.228088 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11261 ms - Host latency: 3.17938 ms (enqueue 0.238879 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1076 ms - Host latency: 3.17529 ms (enqueue 0.272223 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10721 ms - Host latency: 3.17455 ms (enqueue 0.275232 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10767 ms - Host latency: 3.17222 ms (enqueue 0.257782 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11014 ms - Host latency: 3.17499 ms (enqueue 0.242938 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1094 ms - Host latency: 3.17504 ms (enqueue 0.241589 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10909 ms - Host latency: 3.17404 ms (enqueue 0.255444 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1101 ms - Host latency: 3.17426 ms (enqueue 0.229205 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10789 ms - Host latency: 3.17218 ms (enqueue 0.24516 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10971 ms - Host latency: 3.17468 ms (enqueue 0.238275 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11128 ms - Host latency: 3.17461 ms (enqueue 0.230096 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11106 ms - Host latency: 3.17513 ms (enqueue 0.224396 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11153 ms - Host latency: 3.17334 ms (enqueue 0.201392 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1155 ms - Host latency: 3.17884 ms (enqueue 0.211139 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11464 ms - Host latency: 3.17814 ms (enqueue 0.205157 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11545 ms - Host latency: 3.18047 ms (enqueue 0.242291 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11042 ms - Host latency: 3.17445 ms (enqueue 0.219995 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11119 ms - Host latency: 3.17332 ms (enqueue 0.208569 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10951 ms - Host latency: 3.17706 ms (enqueue 0.249036 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1095 ms - Host latency: 3.17261 ms (enqueue 0.225916 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10895 ms - Host latency: 3.17274 ms (enqueue 0.21427 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10972 ms - Host latency: 3.17355 ms (enqueue 0.209741 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11102 ms - Host latency: 3.17402 ms (enqueue 0.212939 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1097 ms - Host latency: 3.17223 ms (enqueue 0.209937 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11196 ms - Host latency: 3.17528 ms (enqueue 0.209888 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11138 ms - Host latency: 3.17948 ms (enqueue 0.329077 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1152 ms - Host latency: 3.18084 ms (enqueue 0.243298 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11406 ms - Host latency: 3.17937 ms (enqueue 0.269385 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11267 ms - Host latency: 3.17675 ms (enqueue 0.217346 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10981 ms - Host latency: 3.17378 ms (enqueue 0.207837 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1093 ms - Host latency: 3.17179 ms (enqueue 0.195349 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10792 ms - Host latency: 3.17194 ms (enqueue 0.208142 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10859 ms - Host latency: 3.1726 ms (enqueue 0.195935 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10852 ms - Host latency: 3.17069 ms (enqueue 0.189172 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10902 ms - Host latency: 3.17338 ms (enqueue 0.212329 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10839 ms - Host latency: 3.16997 ms (enqueue 0.20061 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10912 ms - Host latency: 3.17175 ms (enqueue 0.205994 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11089 ms - Host latency: 3.17285 ms (enqueue 0.198523 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11034 ms - Host latency: 3.17433 ms (enqueue 0.20542 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11063 ms - Host latency: 3.17395 ms (enqueue 0.202441 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11035 ms - Host latency: 3.17324 ms (enqueue 0.208374 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10817 ms - Host latency: 3.17224 ms (enqueue 0.228943 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11116 ms - Host latency: 3.17374 ms (enqueue 0.205579 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11139 ms - Host latency: 3.17568 ms (enqueue 0.221252 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10951 ms - Host latency: 3.17313 ms (enqueue 0.233325 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1097 ms - Host latency: 3.17347 ms (enqueue 0.206311 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11134 ms - Host latency: 3.17422 ms (enqueue 0.196326 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10732 ms - Host latency: 3.17029 ms (enqueue 0.201025 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10968 ms - Host latency: 3.17107 ms (enqueue 0.187463 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11143 ms - Host latency: 3.1761 ms (enqueue 0.203735 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11108 ms - Host latency: 3.17495 ms (enqueue 0.214795 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11108 ms - Host latency: 3.17324 ms (enqueue 0.199609 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11074 ms - Host latency: 3.17354 ms (enqueue 0.207227 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11045 ms - Host latency: 3.17351 ms (enqueue 0.207983 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11006 ms - Host latency: 3.17366 ms (enqueue 0.194849 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11069 ms - Host latency: 3.17373 ms (enqueue 0.201172 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11194 ms - Host latency: 3.17371 ms (enqueue 0.185986 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11143 ms - Host latency: 3.17495 ms (enqueue 0.208545 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11091 ms - Host latency: 3.17466 ms (enqueue 0.202246 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10999 ms - Host latency: 3.17219 ms (enqueue 0.1948 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11033 ms - Host latency: 3.17356 ms (enqueue 0.225537 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11018 ms - Host latency: 3.17195 ms (enqueue 0.202686 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11062 ms - Host latency: 3.17263 ms (enqueue 0.197656 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11355 ms - Host latency: 3.17603 ms (enqueue 0.220557 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11233 ms - Host latency: 3.1752 ms (enqueue 0.195898 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10938 ms - Host latency: 3.171 ms (enqueue 0.189429 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11147 ms - Host latency: 3.1748 ms (enqueue 0.212378 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1124 ms - Host latency: 3.17593 ms (enqueue 0.202295 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11196 ms - Host latency: 3.17493 ms (enqueue 0.205762 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10874 ms - Host latency: 3.17122 ms (enqueue 0.195532 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11147 ms - Host latency: 3.17458 ms (enqueue 0.211475 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11196 ms - Host latency: 3.17444 ms (enqueue 0.187329 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11108 ms - Host latency: 3.17307 ms (enqueue 0.200708 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11057 ms - Host latency: 3.17456 ms (enqueue 0.216235 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11096 ms - Host latency: 3.17385 ms (enqueue 0.198389 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11016 ms - Host latency: 3.17439 ms (enqueue 0.19834 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11125 ms - Host latency: 3.1749 ms (enqueue 0.204468 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10999 ms - Host latency: 3.17227 ms (enqueue 0.20957 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11187 ms - Host latency: 3.17402 ms (enqueue 0.204028 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10823 ms - Host latency: 3.17314 ms (enqueue 0.229614 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.1083 ms - Host latency: 3.17097 ms (enqueue 0.217896 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.10967 ms - Host latency: 3.17266 ms (enqueue 0.201489 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11138 ms - Host latency: 3.17324 ms (enqueue 0.199756 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11201 ms - Host latency: 3.17515 ms (enqueue 0.202515 ms)
# [11/30/2022-09:31:41] [I] Average on 10 runs - GPU latency: 3.11074 ms - Host latency: 3.17422 ms (enqueue 0.211133 ms)
# [11/30/2022-09:31:41] [I]
# [11/30/2022-09:31:41] [I] === Performance summary ===
# [11/30/2022-09:31:41] [I] Throughput: 320.231 qps
# [11/30/2022-09:31:41] [I] Latency: min = 3.16125 ms, max = 3.20078 ms, mean = 3.17434 ms, median = 3.17355 ms, percentile(99%) = 3.1933 ms
# [11/30/2022-09:31:41] [I] Enqueue Time: min = 0.157227 ms, max = 0.604614 ms, mean = 0.216378 ms, median = 0.202637 ms, percentile(99%) = 0.366699 ms
# [11/30/2022-09:31:41] [I] H2D Latency: min = 0.0501709 ms, max = 0.0852051 ms, mean = 0.0583199 ms, median = 0.0563049 ms, percentile(99%) = 0.0733643 ms
# [11/30/2022-09:31:41] [I] GPU Compute Time: min = 3.10065 ms, max = 3.13354 ms, mean = 3.11062 ms, median = 3.11047 ms, percentile(99%) = 3.12292 ms
# [11/30/2022-09:31:41] [I] D2H Latency: min = 0.00244141 ms, max = 0.0109863 ms, mean = 0.0053948 ms, median = 0.00537109 ms, percentile(99%) = 0.00756836 ms
# [11/30/2022-09:31:41] [I] Total Host Walltime: 3.0072 s
# [11/30/2022-09:31:41] [I] Total GPU Compute Time: 2.99553 s
# [11/30/2022-09:31:41] [I] Explanations of the performance metrics are printed in the verbose logs.
# [11/30/2022-09:31:41] [I]
# &&&& PASSED TensorRT.trtexec [TensorRT v8403] # /usr/src/tensorrt/bin/trtexec --onnx=resnet50_pytorch_BS1.onnx --saveEngine=resnet50_engine_pytorch_BS1.engine --explicitBatch --inputIOFormats=fp16:chw --outputIOFormats=fp16:chw --fp16

# %% [markdown]
# ## Config cuda an TRT model

# %%
f = open(f"resnet50_engine_pytorch_BS{BATCH_SIZE}.trt", "rb")
runtime = trt.Runtime(trt.Logger(trt.Logger.WARNING)) 

engine = runtime.deserialize_cuda_engine(f.read())
context = engine.create_execution_context()

# %%
# Full HD resolution
CAPTURE_WIDTH = 1920
CAPTURE_HEIGHT = 1080
resize = True
if resize:
    # 360p resolution
    RESIZE_WIDTH = 360
    RESIZE_HEIGHT = 360

# %%
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, CAPTURE_WIDTH)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, CAPTURE_HEIGHT)
# Out:
# True

# %%
ret, frame = cap.read()
img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
print(f"Original image shape: {img.shape}, dtype: {img.dtype}")
# resize = False
if resize:
    img = skt.resize(img, (RESIZE_WIDTH, RESIZE_HEIGHT))
    print(f"Resized image shape: {img.shape}, dtype: {img.dtype}")
else:
    img = skt.resize(img, (CAPTURE_WIDTH, CAPTURE_HEIGHT))
    print(f"Resized image shape: {img.shape}, dtype: {img.dtype}")
img = np.expand_dims(np.array(img, dtype=np.float32), axis=0) # Expand image to have a batch dimension
print(f"Expanded image shape: {img.shape}, dtype: {img.dtype}")
input_batch = np.array(np.repeat(img, BATCH_SIZE, axis=0), dtype=np.float32) # Repeat across the batch dimension
print(f"Batched image shape: {input_batch.shape}")
# plt.imshow(input_batch[0].astype(np.float32))
# Out:
# Original image shape: (720, 1280, 3), dtype: uint8
# Resized image shape: (360, 360, 3), dtype: float64
# Expanded image shape: (1, 360, 360, 3), dtype: float32
# Batched image shape: (1, 360, 360, 3)

# %%
cap.release()

# %%
def preprocess_image(img):
    norm = torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    result = norm(torch.from_numpy(img).transpose(0,2).transpose(1,2))
    result = np.array(result, dtype=np.float16)
    return result

# %%
# need to set input and output precisions to FP16 to fully enable it
output = np.empty([BATCH_SIZE, 1000], dtype = target_dtype) 

# allocate device memory
d_input = cuda.mem_alloc(1 * np.array(input_batch, dtype=np.float16).nbytes)
d_output = cuda.mem_alloc(1 * output.nbytes)

bindings = [int(d_input), int(d_output)]

stream = cuda.Stream()

# %%
def predict(batch): # result gets copied into output
    # transfer input data to device
    cuda.memcpy_htod_async(d_input, batch, stream)
    # execute model
    context.execute_async_v2(bindings, stream.handle, None)
    # transfer predictions back
    cuda.memcpy_dtoh_async(output, d_output, stream)
    # syncronize threads
    stream.synchronize()
    
    return output

# %%
# Open webcam and start inference
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, CAPTURE_WIDTH)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, CAPTURE_HEIGHT)
font = cv2.FONT_HERSHEY_SIMPLEX
fontScale = 0.5
fontColor = (10,10,10)
lineThickness= 1
lineType = cv2.LINE_AA
pos = 30
do_preprocess = True

while True:
    if 5 >= BATCH_SIZE:
        ret, frame = cap.read()
        img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        if resize:
            img = skt.resize(img, (RESIZE_WIDTH, RESIZE_HEIGHT))
        else:
            img = skt.resize(img, (CAPTURE_WIDTH, CAPTURE_HEIGHT))
        img = np.expand_dims(np.array(img, dtype=np.float32), axis=0)
    t0 = time.time()
    ret, frame = cap.read()
    t_frame = time.time()
    pos = 30
    cv2.putText(frame, f"Image resolution: {frame.shape}", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
    pos += 20
    cv2.putText(frame, f"Open frame time: {((t_frame - t0)*1000):.2f} ms", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
    pos += 20
    if not ret:
        continue

    # Preprocess image
    t1 = time.time()
    img = frame.copy()
    t_copy = time.time()
    cv2.putText(frame, f"Copy frame time: {((t_copy - t1)*1000):.2f} ms", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
    pos += 20
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    t_rgb = time.time()
    cv2.putText(frame, f"RGB conversion time: {((t_rgb - t_copy)*1000):.2f} ms", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
    pos += 20
    if resize:
        img = skt.resize(img, (RESIZE_HEIGHT, RESIZE_HEIGHT))
    else:
        img = skt.resize(img, (CAPTURE_WIDTH, CAPTURE_HEIGHT))
    t_resize = time.time()
    cv2.putText(frame, f"Resize time: {((t_resize - t_rgb)*1000):.2f} ms", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
    pos += 20
    img = np.expand_dims(np.array(img, dtype=np.float32), axis=0) # Expand image to have a batch dimension
    t_expand = time.time()
    cv2.putText(frame, f"Expand time: {((t_expand - t_resize)*1000):.2f} ms", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
    pos += 20
    if BATCH_SIZE > 1:
        input_batch = np.array(np.repeat(img, BATCH_SIZE, axis=0), dtype=np.float32) # Repeat across the batch dimension
        t_repeat = time.time()
        cv2.putText(frame, f"Repeat time: {((t_repeat - t_expand)*1000):.2f} ms", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
        pos += 20
    else:
        input_batch = img.copy()
    if do_preprocess:
        t_input = time.time()
        preprocessed_image = np.array([preprocess_image(image) for image in input_batch])
        t_preprocess = time.time()
        cv2.putText(frame, f"Preprocess time: {((t_preprocess - t_input)*1000):.2f} ms", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
        pos += 20
        cv2.putText(frame, f"preprocessed_image shape: {preprocessed_image.shape}", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
        pos += 20
        cv2.putText(frame, f"input_batch shape: {input_batch.shape}", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
        pos += 20
    else:
        preprocessed_image = input_batch[0].astype(np.float16)
    t_total_preprocess = time.time()
    cv2.putText(frame, f"Total preprocess time: {((t_total_preprocess - t1)*1000):.2f} ms", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
    pos += 20

    # Inference
    start = time.time()
    outputs = predict(preprocessed_image)
    end = time.time()
    cv2.putText(frame, f"Inference time: {((end - start)*1000):.2f} ms", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
    pos += 20

    # Postprocess
    t2 = time.time()
    idx = outputs[0].argmax()
    t_postprocess = time.time()
    cv2.putText(frame, f"Predicted: {idx}-{labels[idx]}", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
    pos += 20
    cv2.putText(frame, f"Postprocess time: {((t_postprocess - t2)*1000):.2f} ms", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
    pos += 20

    # FPS
    T = time.time() - t0
    cv2.putText(frame, f"Total time: {(T*1000):.2f} ms", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
    pos += 20
    cv2.putText(frame, f"FPS: {1/T:.2f}", (10, pos), font, fontScale, fontColor, lineThickness, lineType)
    pos += 20

    # Display
    cv2.imshow("frame", frame)
    if cv2.waitKey(1) == ord('q'):
        break


cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()
