# %% [markdown]
# <center><img src="images/DLI Header.png" alt="Header" width="400"></center>

# %% [markdown]
# # 1.0 Object Detection Application
# In this notebook, you'll work with the `deepstream-test1` reference application to find objects in a video stream, annotate them with bounding boxes, and output the annotated stream along with a count of the objects found.

# %% [markdown]
# <img src="images/01_threethingsio.png">

# %% [markdown]
# You'll follow the steps below to build your own applications based on the reference app:
#
# **[1.1 Build a Basic DeepStream Pipeline](#1.1-Build-a-Basic-DeepStream-Pipeline)**<br>
# &nbsp; &nbsp; &nbsp; [1.1.1 Sample Application - `deepstream-test1`](#1.1.1-Sample-Application---deepstream-test1)<br>
# &nbsp; &nbsp; &nbsp; [1.1.2 Sample Application Plus RTSP - `deepstream-test1-rtsp-out`](#1.1.2-Sample-Application-Plus-RTSP---deepstream-test1-rtsp-out)<br>
# &nbsp; &nbsp; &nbsp; [1.1.3 Putting the Pipeline Together](#1.1.3-Putting-the-Pipeline-Together)<br>
# &nbsp; &nbsp; &nbsp; [1.1.4 Exercise: Run the Base Application](#1.1.4-Exercise:-Run-the-Base-Application)<br>
# **[1.2 Configure an Object Detection Model](#1.2-Configure-an-Object-Detection-Model)**<br>
# &nbsp; &nbsp; &nbsp; [1.2.1 `Gst-nvinfer` Configuration File](#1.2.1-Gst-nvinfer-Configuration-File)<br>
# &nbsp; &nbsp; &nbsp; [1.2.2 Exercise: Detect Only Two Object Types](#1.2.2-Exercise:-Detect-Only-Two-Object-Types)<br>

# %% [markdown]
# # 1.1 Build a Basic DeepStream Pipeline
# The framework used to build a DeepStream application is a GStreamer **pipeline** consisting of a video input stream, a series of **elements** or **plugins** to process the stream, and an insightful output stream.  Plugins along the pipeline are sometimes referred to as **filters**, because they have both an input, also called the **sink**, and an output, called the **source**. The plugins at the start and end of the pipeline only have a source or sink and are referred to generally as source or sink plugins.
#
# In the pipeline, the source **pad** of one plugin connects to the sink pad of the next in line.  The source includes data extracted from the processing, the **metadata**, which can be used for annotation of the video and other insights about the input stream.

# %% [markdown]
# <img src="../../images/01_building_blocks.png">

# %% [markdown]
# ## 1.1.1 Sample Application - `deepstream-test1`
# The DeepStream SDK includes plugins for building a pipeline, and reference applications. For example, the `deepstream_test1` reference application can take a street scene video file as input, use object detection to find vehicles, people, bicycles, and road signs within the video, and output a video stream with bounding boxes around the objects found.

# %% [markdown]
# <img src="../../images/01_exampleio2.png">

# %% [markdown]
# The reference test applications are in the `sources` folder of the DeepStream SDK, which is located at `/opt/nvidia/deepstream/deepstream`.  This is linked in your workspace as simply `deepstream`.
#
# You can open and look at the Python code for the `deepstream-test1` app at [deepstream/sources/deepstream_python_apps/apps/deepstream-test1/deepstream_test_1.py](deepstream/sources/deepstream_python_apps/apps/deepstream-test1/deepstream_test_1.py)

# %% [markdown]
# Looking at the code, we can find where all the plugins are instantiated in `main()` definition using the `Gst.ElementFactory.make()` method.  This is a good way to see exactly which plugins are in the pipeline *(Note: the sample snippets shown are abbreviated code for clarity purposes)*:

# %% [markdown]
# ```python
#     # Create gstreamer elements
#     # Create Pipeline element that will form a connection of other elements
#     print("Creating Pipeline \n ")
#     pipeline = Gst.Pipeline()
#
#     # Source element for reading from the file
#     print("Creating Source \n ")
#     source = Gst.ElementFactory.make("filesrc", "file-source")
#
#     # Since the data format in the input file is elementary h264 stream,
#     # we need a h264parser
#     print("Creating H264Parser \n")
#     h264parser = Gst.ElementFactory.make("h264parse", "h264-parser")
#
#     # Use nvdec_h264 for hardware accelerated decode on GPU
#     print("Creating Decoder \n")
#     decoder = Gst.ElementFactory.make("nvv4l2decoder", "nvv4l2-decoder")
#
#     # Create nvstreammux instance to form batches from one or more sources.
#     streammux = Gst.ElementFactory.make("nvstreammux", "Stream-muxer")
#
#     # Use nvinfer to run inferencing on decoder's output,
#     # behaviour of inferencing is set through config file
#     pgie = Gst.ElementFactory.make("nvinfer", "primary-inference")
#
#     # Use convertor to convert from NV12 to RGBA as required by nvosd
#     nvvidconv = Gst.ElementFactory.make("nvvideoconvert", "convertor")
#
#     # Create OSD to draw on the converted RGBA buffer
#     nvosd = Gst.ElementFactory.make("nvdsosd", "onscreendisplay")
#
#     # Finally render the osd output
#     if is_aarch64():
#         transform = Gst.ElementFactory.make("nvegltransform", "nvegl-transform")
#
#     sink = Gst.ElementFactory.make("nveglglessink", "nvvideo-renderer")
# ```

# %% [markdown]
# We see that the input is a file source, `filesrc`, in H.264 video format.  It is parsed (`h264parse`), decoded (`nvv4l2decoder`), batched (`nvstreammux`), and then run through the `nvinfer` inference engine to detect objects.  A buffer is created with `nvvideoconvert` so that bounding boxes can be overlaid on the video images with the `nvdsosd` plugin.  Finally, the output is rendered, in this case for a display using `nvegltransform` and `nvegglessink`.

# %% [markdown]
# ## 1.1.2 Sample Application Plus RTSP - `deepstream-test1-rtsp-out`
# For the purposes of this lab, which runs headless on a Jetson Nano connected to a laptop, the video stream must be converted to a format that can be transferred to the laptop media player.  This is accomplished with additional plugins and some logic for the rendering portion of the pipeline. Review the code in [deepstream/sources/deepstream_python_apps/apps/deepstream-test1-rtsp-out/deepstream_test1_rtsp_out.py](deepstream/sources/deepstream_python_apps/apps/deepstream-test1-rtsp-out/deepstream_test1_rtsp_out.py).<br><br>
# Scrolling down to `main()`, we can see that there are a few differences in the rendering plugins after the OSD (On Screen Display) creation.  Instead of using the video sink, the stream is filtered, encoded, formatted for RTP payloads, and finally sinked as UDP packets:

# %% [markdown]
# ```python
#
#     # Create OSD to draw on the converted RGBA buffer
#     nvosd = Gst.ElementFactory.make("nvdsosd", "onscreendisplay")
#     nvvidconv_postosd = Gst.ElementFactory.make("nvvideoconvert", "convertor_postosd")
#
#     # Create a caps filter
#     caps = Gst.ElementFactory.make("capsfilter", "filter")
#
#     # Make the encoder
#     if codec == "H264":
#         encoder = Gst.ElementFactory.make("nvv4l2h264enc", "encoder")
#     elif codec == "H265":
#         encoder = Gst.ElementFactory.make("nvv4l2h265enc", "encoder")
#
#     # Make the payload-encode video into RTP packets
#     if codec == "H264":
#         rtppay = Gst.ElementFactory.make("rtph264pay", "rtppay")
#     elif codec == "H265":
#         rtppay = Gst.ElementFactory.make("rtph265pay", "rtppay")
#
#     # Make the UDP sink
#     updsink_port_num = 5400
#     sink = Gst.ElementFactory.make("udpsink", "udpsink")
#
# ```

# %% [markdown]
# ## 1.1.3 Putting the Pipeline Together
# The plugins are put in a pipeline with the `pipeline.add()` method:
#
# ```python
#     pipeline.add(source)
#     pipeline.add(h264parser)
#     pipeline.add(decoder)
#     pipeline.add(streammux)
#     pipeline.add(pgie)
#     pipeline.add(nvvidconv)
#     pipeline.add(nvosd)
#     pipeline.add(nvvidconv_postosd)
#     pipeline.add(caps)
#     pipeline.add(encoder)
#     pipeline.add(rtppay)
#     pipeline.add(sink)
# ```
#
# Each plugin is then connected in order using its `.link()` method. Generally, this is as simple as
#
# ```python
#     source_plugin.link(sink_plugin)
# ```
#
# However, when connecting a source to nvstreammux (`streammux` or "the muxer"), a new sink pad must be requested from the muxer, and that pad explicitly linked to the previous plugin's source pad.  In the code, there is a `srcpad` into `streammux` and a `srcpad` out of `decoder` defined.  These are then linked together directly.
#
# ```python
#     source.link(h264parser)
#     h264parser.link(decoder)
#     sinkpad = streammux.get_request_pad("sink_0")
#     srcpad = decoder.get_static_pad("src")
#     srcpad.link(sinkpad)
#     streammux.link(pgie)
#     pgie.link(nvvidconv)
#     nvvidconv.link(nvosd)
#     nvosd.link(nvvidconv_postosd)
#     nvvidconv_postosd.link(caps)
#     caps.link(encoder)
#     encoder.link(rtppay)
#     rtppay.link(sink)
# ```

# %% [markdown]
# In summary, the pipeline for this app consists of the following plugins (ordered):
#
# - `GstFileSrc` - reads the video data from file
# - `GstH264Parse` - parses the incoming H264 stream
# - `Gst-nvv4l2decoder` - hardware accelerated decoder; decodes video streams using NVDEC
# - `Gst-nvstreammux` - batch video streams before sending for AI inference
# - `Gst-nvinfer` - runs inference using TensorRT
# - `Gst-nvvideoconvert` - performs video color format conversion (I420 to RGBA)
# - `Gst-nvdsosd` - draw bounding boxes, text and region of interest (ROI) polygons
# - `Gst-nvvideoconvert` - performs video color format conversion (RGBA to I420)
# - `GstCapsFilter` - enforces limitations on data (no data modification)
# - `Gst-nvv4l2h264enc` - encodes RAW data in I420 format to H264
# - `GstRtpH264Pay` - converts H264 encoded Payload to RTP packets (RFC 3984)
# - `GstUDPSink` - sends UDP packets to the network. When paired with RTP payloader (`Gst-rtph264pay`) it can implement RTP streaming

# %% [markdown]
# ## 1.1.4 Exercise: Run the Base Application
# In this exercise, we'll feed a simple video file through the pipeline and view the result using an RTSP stream.
#
# In the `deepstream-test1`/`deepstream-test1-rtsp-out` example app, object detection is performed on a per-frame basis. Counts for `Vehicle` and `Person` objects are also tracked.  Bounding boxes are drawn around the objects identified, and a counter display is overlaid in the upper left corner of the video.
#
# To begin, assign some user-friendly names to paths.  Next, list the available sample apps and video streams.

# %%
# Set some path locations for readability
PYTHON_APPS = '/dli/task/deepstream_apps/deepstream-test1-rtsp-out' # '/opt/nvidia/deepstream/deepstream/sources/deepstream_python_apps/apps'
STREAMS = '/opt/nvidia/deepstream/deepstream/samples/streams'

# %%
# List the sample Python apps available
# !ls $PYTHON_APPS
# Out:
# 01_ObjDetect.ipynb  deepstream-test1-rtsp-out.ipynb  dstest1_pgie_config.txt
# README		    deepstream_test1_rtsp_out.py

# %%
# List the sample video streams available
# !ls $STREAMS
# Out:
# sample_1080p_h264.mp4  sample_720p.mp4	      sample_qHD.mp4	     yoga.jpg
# sample_1080p_h265.mp4  sample_cam6.mp4	      sample_ride_bike.mov   yoga.mp4
# sample_720p.h264       sample_industrial.jpg  sample_run.mov
# sample_720p.jpg        sample_push.mov	      sample_walk.mov
# sample_720p.mjpeg      sample_qHD.h264	      sonyc_mixed_audio.wav

# %% [markdown]
# Before running the app, check out the script usage with the `--help` option.

# %%
# Check usage of the test1 app with the help option
# !cd $PYTHON_APPS \
    && python3 deepstream_test1_rtsp_out.py --help
# Out:
# usage: deepstream_test1_rtsp_out.py [-h] -i INPUT [-d {H264,H265}]
#                                     [-c {H264,H265}] [-b BITRATE] [-p PORT]
#                                     [-x CONFIG_FILE] [-m MOUNT_POINT]
#
# RTSP Output Sample Application Help
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -i INPUT, --input INPUT
#                         Path to input H264 elementry stream (required)
#   -d {H264,H265}, --input_codec {H264,H265}
#                         Input Codec H264/H265, default=H264
#   -c {H264,H265}, --codec {H264,H265}
#                         RTSP Streaming Codec H264/H265, default=H264
#   -b BITRATE, --bitrate BITRATE
#                         Set the encoding bitrate, default=4000000
#   -p PORT, --port PORT  Port of RTSP stream, default=8554
#   -x CONFIG_FILE, --config_file CONFIG_FILE
#                         Config file, default=dstest1_pgie_config.txt
#   -m MOUNT_POINT, --mount_point MOUNT_POINT
#                         Mount point RTSP, default=rtsp_out

# %% [markdown]
# #### Run the DeepStream app
# If using VLC media player, open the app on your computer:
# - Pull down the "Media" menu and select the "Open Network Stream" dialog.
# - Set the URL to `rtsp://192.168.55.1:8554/ds-test`.
# - Optionally, add a wait delay to VLC:
#    - Click "Show more options" in the dialog.
#    - Add ` :ipv4=120000` to the "Edit Options" line to add a 120 second delay.
# - Start execution of the cell below.
# - Click "Play" on your VLC media player *after* you start the cell execution.
#
# The stream will start from the Jetson Nano and display in the media player.  There is a delay while the model `.engine` file is built.
#
# If VLC fails, start it again. Close the VLC fail notice and press the "play" triangle.

# %%
# Run the app
# !cd $PYTHON_APPS \
    && python3 deepstream_test1_rtsp_out.py -i $STREAMS/sample_720p.h264
# Out:
#
#  ******************* Create gstreamer elements *******************
#  ******************* Creating Pipeline
#  ******************* Creating Source, reads the video data from file
#  ******************* Creating H264Parser, parses the incoming H264/H265 stream
#  ******************* Creating Decoder, hardware accelerated decoder; decodes video streams using NVDEC
#  ******************* Creating nvstreammux instance, batch video streams before sending for AI inference
#  ******************* Creating nvinfer, runs inference using TensorRT
#  ******************* Creating convertor, performs video color format conversion (I420 to RGBA)
#  ******************* Creating OSD, draw bounding boxes, text and region of interest (ROI) polygons
#  ******************* Performs video color format conversion (RGBA to I420)
#  ******************* Creating caps filter, enforces limitations on data (no data modification)
#  ******************* Creating H264 Encoder, encodes RAW data in I420 format to H264
#  ******************* Is aarch64
#  ******************* Make the payload-encode video into RTP packets, converts H264/H265 encoded Payload to RTP packets (RFC 3984)
#  ******************* Creating H264 rtppay
#  ******************* Make the UDP sink in port 5400, sends UDP packets to the network. When paired with RTP payloader (Gst-rtph264pay) it can implement RTP streaming
#
#  ******************* Configure sink properties *******************
#
#  ******************* Configure source properties *******************
#  ******************* Playing file /opt/nvidia/deepstream/deepstream/samples/streams/sample_720p.h264
#
#  ******************* Configure inference properties *******************
#
#  ******************* Adding elements to Pipeline *******************
#
#  ******************* Linking elements in the Pipeline *******************
#  ******************* file-source -> h264-parser -> nvh264-decoder ->
#  ******************* nvinfer -> nvvidconv -> nvosd -> nvvidconv_postosd ->
#  ******************* caps -> encoder -> rtppay -> udpsink
#
#  ******************* create an event loop and feed gstreamer bus mesages to it *******************
#
#  ******************* Configure RTSP port *******************
#
#  *** DeepStream: Launched RTSP Streaming at rtsp://localhost:8554/rtsp_out ***
#
#
#
#  ******************* Get metadata from OSD element *******************
#  ******************* Get sink of OSD element
#  ******************* Get probe to get informed of the meta data generated
# Starting pipeline
#
# Opening in BLOCKING MODE
# Opening in BLOCKING MODE
# 0:00:02.219914333   402      0x6816c30 WARN                 nvinfer gstnvinfer.cpp:635:gst_nvinfer_logger:<primary-inference> NvDsInferContext[UID 1]: Warning from NvDsInferContextImpl::initialize() <nvdsinfer_context_impl.cpp:1161> [UID = 1]: Warning, OpenCV has been deprecated. Using NMS for clustering instead of cv::groupRectangles with topK = 20 and NMS Threshold = 0.5
# ERROR: Deserialize engine failed because file path: /opt/nvidia/deepstream/deepstream-6.0/samples/models/Primary_Detector/resnet10.caffemodel_b1_gpu0_int8.engine open error
# 0:00:06.451191415   402      0x6816c30 WARN                 nvinfer gstnvinfer.cpp:635:gst_nvinfer_logger:<primary-inference> NvDsInferContext[UID 1]: Warning from NvDsInferContextImpl::deserializeEngineAndBackend() <nvdsinfer_context_impl.cpp:1889> [UID = 1]: deserialize engine from file :/opt/nvidia/deepstream/deepstream-6.0/samples/models/Primary_Detector/resnet10.caffemodel_b1_gpu0_int8.engine failed
# 0:00:06.452338443   402      0x6816c30 WARN                 nvinfer gstnvinfer.cpp:635:gst_nvinfer_logger:<primary-inference> NvDsInferContext[UID 1]: Warning from NvDsInferContextImpl::generateBackendContext() <nvdsinfer_context_impl.cpp:1996> [UID = 1]: deserialize backend context from engine from file :/opt/nvidia/deepstream/deepstream-6.0/samples/models/Primary_Detector/resnet10.caffemodel_b1_gpu0_int8.engine failed, try rebuild
# 0:00:06.452385370   402      0x6816c30 INFO                 nvinfer gstnvinfer.cpp:638:gst_nvinfer_logger:<primary-inference> NvDsInferContext[UID 1]: Info from NvDsInferContextImpl::buildModel() <nvdsinfer_context_impl.cpp:1914> [UID = 1]: Trying to create engine from model files
# WARNING: INT8 not supported by platform. Trying FP16 mode.
# 0:01:23.333095856   402      0x6816c30 INFO                 nvinfer gstnvinfer.cpp:638:gst_nvinfer_logger:<primary-inference> NvDsInferContext[UID 1]: Info from NvDsInferContextImpl::buildModel() <nvdsinfer_context_impl.cpp:1947> [UID = 1]: serialize cuda engine to file: /opt/nvidia/deepstream/deepstream-6.0/samples/models/Primary_Detector/resnet10.caffemodel_b1_gpu0_fp16.engine successfully
# INFO: [Implicit Engine Info]: layers num: 3
# 0   INPUT  kFLOAT input_1         3x368x640
# 1   OUTPUT kFLOAT conv2d_bbox     16x23x40
# 2   OUTPUT kFLOAT conv2d_cov/Sigmoid 4x23x40
#
# 0:01:23.590480183   402      0x6816c30 INFO                 nvinfer gstnvinfer_impl.cpp:313:notifyLoadModelStatus:<primary-inference> [UID 1]: Load new model:dstest1_pgie_config.txt sucessfully
# NvMMLiteOpen : Block : BlockType = 261
# NVMEDIA: Reading vendor.tegra.display-size : status: 6
# NvMMLiteBlockCreate : Block : BlockType = 261
# NvMMLiteOpen : Block : BlockType = 4
# ===== NVMEDIA: NVENC =====
# NvMMLiteBlockCreate : Block : BlockType = 4
# Frame Number=0 Number of Objects=9 Vehicle_count=6 Person_count=3
# H264: Profile = 66, Level = 0
# NVMEDIA_ENC: bBlitMode is set to TRUE
# Frame Number=1 Number of Objects=10 Vehicle_count=7 Person_count=3
# Frame Number=2 Number of Objects=10 Vehicle_count=7 Person_count=3
# Frame Number=3 Number of Objects=9 Vehicle_count=5 Person_count=4
# Frame Number=4 Number of Objects=8 Vehicle_count=5 Person_count=3
# Frame Number=5 Number of Objects=7 Vehicle_count=5 Person_count=2
# Frame Number=6 Number of Objects=9 Vehicle_count=6 Person_count=3
# Frame Number=7 Number of Objects=10 Vehicle_count=7 Person_count=3
# Frame Number=8 Number of Objects=10 Vehicle_count=7 Person_count=3
# Frame Number=9 Number of Objects=11 Vehicle_count=8 Person_count=3
# Frame Number=10 Number of Objects=10 Vehicle_count=7 Person_count=3
# Frame Number=11 Number of Objects=9 Vehicle_count=7 Person_count=2
# Frame Number=12 Number of Objects=9 Vehicle_count=7 Person_count=2
# Frame Number=13 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=14 Number of Objects=9 Vehicle_count=7 Person_count=2
# Frame Number=15 Number of Objects=9 Vehicle_count=7 Person_count=2
# Frame Number=16 Number of Objects=9 Vehicle_count=7 Person_count=2
# Frame Number=17 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=18 Number of Objects=14 Vehicle_count=10 Person_count=4
# Frame Number=19 Number of Objects=11 Vehicle_count=8 Person_count=3
# Frame Number=20 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=21 Number of Objects=12 Vehicle_count=9 Person_count=3
# Frame Number=22 Number of Objects=16 Vehicle_count=13 Person_count=3
# Frame Number=23 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=24 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=25 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=26 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=27 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=28 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=29 Number of Objects=18 Vehicle_count=15 Person_count=3
# Frame Number=30 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=31 Number of Objects=15 Vehicle_count=11 Person_count=4
# Frame Number=32 Number of Objects=13 Vehicle_count=9 Person_count=4
# Frame Number=33 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=34 Number of Objects=20 Vehicle_count=15 Person_count=5
# Frame Number=35 Number of Objects=21 Vehicle_count=16 Person_count=5
# Frame Number=36 Number of Objects=25 Vehicle_count=17 Person_count=8
# Frame Number=37 Number of Objects=26 Vehicle_count=20 Person_count=6
# Frame Number=38 Number of Objects=21 Vehicle_count=17 Person_count=4
# Frame Number=39 Number of Objects=19 Vehicle_count=13 Person_count=6
# Frame Number=40 Number of Objects=20 Vehicle_count=14 Person_count=6
# Frame Number=41 Number of Objects=21 Vehicle_count=16 Person_count=5
# Frame Number=42 Number of Objects=21 Vehicle_count=17 Person_count=4
# Frame Number=43 Number of Objects=24 Vehicle_count=19 Person_count=5
# Frame Number=44 Number of Objects=20 Vehicle_count=16 Person_count=4
# Frame Number=45 Number of Objects=22 Vehicle_count=18 Person_count=4
# Frame Number=46 Number of Objects=18 Vehicle_count=15 Person_count=3
# Frame Number=47 Number of Objects=18 Vehicle_count=14 Person_count=4
# Frame Number=48 Number of Objects=16 Vehicle_count=12 Person_count=4
# Frame Number=49 Number of Objects=15 Vehicle_count=11 Person_count=4
# Frame Number=50 Number of Objects=13 Vehicle_count=9 Person_count=4
# Frame Number=51 Number of Objects=12 Vehicle_count=9 Person_count=3
# Frame Number=52 Number of Objects=12 Vehicle_count=9 Person_count=3
# Frame Number=53 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=54 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=55 Number of Objects=19 Vehicle_count=12 Person_count=7
# Frame Number=56 Number of Objects=20 Vehicle_count=14 Person_count=6
# Frame Number=57 Number of Objects=23 Vehicle_count=16 Person_count=7
# Frame Number=58 Number of Objects=23 Vehicle_count=18 Person_count=5
# Frame Number=59 Number of Objects=25 Vehicle_count=20 Person_count=5
# Frame Number=60 Number of Objects=25 Vehicle_count=19 Person_count=6
# Frame Number=61 Number of Objects=22 Vehicle_count=16 Person_count=6
# Frame Number=62 Number of Objects=23 Vehicle_count=15 Person_count=8
# Frame Number=63 Number of Objects=21 Vehicle_count=13 Person_count=8
# Frame Number=64 Number of Objects=22 Vehicle_count=13 Person_count=9
# Frame Number=65 Number of Objects=18 Vehicle_count=12 Person_count=6
# Frame Number=66 Number of Objects=16 Vehicle_count=9 Person_count=7
# Frame Number=67 Number of Objects=18 Vehicle_count=11 Person_count=7
# Frame Number=68 Number of Objects=18 Vehicle_count=12 Person_count=6
# Frame Number=69 Number of Objects=21 Vehicle_count=15 Person_count=6
# Frame Number=70 Number of Objects=24 Vehicle_count=16 Person_count=8
# Frame Number=71 Number of Objects=20 Vehicle_count=14 Person_count=6
# Frame Number=72 Number of Objects=25 Vehicle_count=19 Person_count=6
# Frame Number=73 Number of Objects=26 Vehicle_count=19 Person_count=7
# Frame Number=74 Number of Objects=24 Vehicle_count=19 Person_count=5
# Frame Number=75 Number of Objects=20 Vehicle_count=15 Person_count=5
# Frame Number=76 Number of Objects=19 Vehicle_count=14 Person_count=5
# Frame Number=77 Number of Objects=19 Vehicle_count=13 Person_count=6
# Frame Number=78 Number of Objects=23 Vehicle_count=17 Person_count=6
# Frame Number=79 Number of Objects=17 Vehicle_count=12 Person_count=5
# Frame Number=80 Number of Objects=19 Vehicle_count=13 Person_count=6
# Frame Number=81 Number of Objects=19 Vehicle_count=13 Person_count=6
# Frame Number=82 Number of Objects=18 Vehicle_count=12 Person_count=6
# Frame Number=83 Number of Objects=19 Vehicle_count=12 Person_count=7
# Frame Number=84 Number of Objects=16 Vehicle_count=10 Person_count=6
# Frame Number=85 Number of Objects=16 Vehicle_count=10 Person_count=6
# Frame Number=86 Number of Objects=15 Vehicle_count=9 Person_count=6
# Frame Number=87 Number of Objects=16 Vehicle_count=10 Person_count=6
# Frame Number=88 Number of Objects=19 Vehicle_count=13 Person_count=6
# Frame Number=89 Number of Objects=17 Vehicle_count=12 Person_count=5
# Frame Number=90 Number of Objects=16 Vehicle_count=11 Person_count=5
# Frame Number=91 Number of Objects=17 Vehicle_count=11 Person_count=6
# Frame Number=92 Number of Objects=20 Vehicle_count=14 Person_count=6
# Frame Number=93 Number of Objects=24 Vehicle_count=18 Person_count=6
# Frame Number=94 Number of Objects=19 Vehicle_count=13 Person_count=6
# Frame Number=95 Number of Objects=21 Vehicle_count=15 Person_count=6
# Frame Number=96 Number of Objects=19 Vehicle_count=13 Person_count=6
# Frame Number=97 Number of Objects=17 Vehicle_count=12 Person_count=5
# Frame Number=98 Number of Objects=17 Vehicle_count=13 Person_count=4
# Frame Number=99 Number of Objects=15 Vehicle_count=11 Person_count=4
# Frame Number=100 Number of Objects=17 Vehicle_count=13 Person_count=4
# Frame Number=101 Number of Objects=14 Vehicle_count=10 Person_count=4
# Frame Number=102 Number of Objects=18 Vehicle_count=14 Person_count=4
# Frame Number=103 Number of Objects=17 Vehicle_count=13 Person_count=4
# Frame Number=104 Number of Objects=16 Vehicle_count=12 Person_count=4
# Frame Number=105 Number of Objects=15 Vehicle_count=11 Person_count=4
# Frame Number=106 Number of Objects=15 Vehicle_count=11 Person_count=4
# Frame Number=107 Number of Objects=16 Vehicle_count=12 Person_count=4
# Frame Number=108 Number of Objects=14 Vehicle_count=10 Person_count=4
# Frame Number=109 Number of Objects=11 Vehicle_count=7 Person_count=4
# Frame Number=110 Number of Objects=14 Vehicle_count=9 Person_count=5
# Frame Number=111 Number of Objects=14 Vehicle_count=8 Person_count=6
# Frame Number=112 Number of Objects=13 Vehicle_count=7 Person_count=6
# Frame Number=113 Number of Objects=13 Vehicle_count=7 Person_count=6
# Frame Number=114 Number of Objects=13 Vehicle_count=7 Person_count=6
# Frame Number=115 Number of Objects=14 Vehicle_count=8 Person_count=6
# Frame Number=116 Number of Objects=13 Vehicle_count=8 Person_count=5
# Frame Number=117 Number of Objects=13 Vehicle_count=8 Person_count=5
# Frame Number=118 Number of Objects=13 Vehicle_count=7 Person_count=6
# Frame Number=119 Number of Objects=12 Vehicle_count=7 Person_count=5
# Frame Number=120 Number of Objects=15 Vehicle_count=9 Person_count=6
# Frame Number=121 Number of Objects=16 Vehicle_count=8 Person_count=8
# Frame Number=122 Number of Objects=13 Vehicle_count=7 Person_count=6
# Frame Number=123 Number of Objects=15 Vehicle_count=8 Person_count=7
# Frame Number=124 Number of Objects=17 Vehicle_count=9 Person_count=8
# Frame Number=125 Number of Objects=12 Vehicle_count=5 Person_count=7
# Frame Number=126 Number of Objects=14 Vehicle_count=6 Person_count=8
# Frame Number=127 Number of Objects=16 Vehicle_count=8 Person_count=8
# Frame Number=128 Number of Objects=13 Vehicle_count=7 Person_count=6
# Frame Number=129 Number of Objects=13 Vehicle_count=7 Person_count=6
# Frame Number=130 Number of Objects=15 Vehicle_count=7 Person_count=8
# Frame Number=131 Number of Objects=16 Vehicle_count=9 Person_count=7
# Frame Number=132 Number of Objects=12 Vehicle_count=6 Person_count=6
# Frame Number=133 Number of Objects=11 Vehicle_count=5 Person_count=6
# Frame Number=134 Number of Objects=14 Vehicle_count=7 Person_count=7
# Frame Number=135 Number of Objects=13 Vehicle_count=6 Person_count=7
# Frame Number=136 Number of Objects=13 Vehicle_count=7 Person_count=6
# Frame Number=137 Number of Objects=12 Vehicle_count=6 Person_count=6
# Frame Number=138 Number of Objects=15 Vehicle_count=7 Person_count=8
# Frame Number=139 Number of Objects=17 Vehicle_count=9 Person_count=8
# Frame Number=140 Number of Objects=18 Vehicle_count=11 Person_count=7
# Frame Number=141 Number of Objects=19 Vehicle_count=12 Person_count=7
# Frame Number=142 Number of Objects=17 Vehicle_count=11 Person_count=6
# Frame Number=143 Number of Objects=16 Vehicle_count=10 Person_count=6
# Frame Number=144 Number of Objects=17 Vehicle_count=11 Person_count=6
# Frame Number=145 Number of Objects=17 Vehicle_count=10 Person_count=7
# Frame Number=146 Number of Objects=15 Vehicle_count=9 Person_count=6
# Frame Number=147 Number of Objects=17 Vehicle_count=11 Person_count=6
# Frame Number=148 Number of Objects=15 Vehicle_count=9 Person_count=6
# Frame Number=149 Number of Objects=19 Vehicle_count=13 Person_count=6
# Frame Number=150 Number of Objects=18 Vehicle_count=11 Person_count=7
# Frame Number=151 Number of Objects=21 Vehicle_count=14 Person_count=7
# Frame Number=152 Number of Objects=20 Vehicle_count=11 Person_count=9
# Frame Number=153 Number of Objects=18 Vehicle_count=11 Person_count=7
# Frame Number=154 Number of Objects=18 Vehicle_count=12 Person_count=6
# Frame Number=155 Number of Objects=17 Vehicle_count=11 Person_count=6
# Frame Number=156 Number of Objects=18 Vehicle_count=11 Person_count=7
# Frame Number=157 Number of Objects=17 Vehicle_count=11 Person_count=6
# Frame Number=158 Number of Objects=17 Vehicle_count=11 Person_count=6
# Frame Number=159 Number of Objects=20 Vehicle_count=13 Person_count=6
# Frame Number=160 Number of Objects=23 Vehicle_count=13 Person_count=9
# Frame Number=161 Number of Objects=20 Vehicle_count=11 Person_count=8
# Frame Number=162 Number of Objects=23 Vehicle_count=13 Person_count=9
# Frame Number=163 Number of Objects=18 Vehicle_count=11 Person_count=7
# Frame Number=164 Number of Objects=18 Vehicle_count=12 Person_count=6
# Frame Number=165 Number of Objects=17 Vehicle_count=10 Person_count=6
# Frame Number=166 Number of Objects=15 Vehicle_count=9 Person_count=6
# Frame Number=167 Number of Objects=16 Vehicle_count=9 Person_count=6
# Frame Number=168 Number of Objects=15 Vehicle_count=8 Person_count=6
# Frame Number=169 Number of Objects=18 Vehicle_count=10 Person_count=7
# Frame Number=170 Number of Objects=18 Vehicle_count=11 Person_count=7
# Frame Number=171 Number of Objects=17 Vehicle_count=11 Person_count=6
# Frame Number=172 Number of Objects=17 Vehicle_count=11 Person_count=6
# Frame Number=173 Number of Objects=18 Vehicle_count=10 Person_count=7
# Frame Number=174 Number of Objects=17 Vehicle_count=11 Person_count=5
# Frame Number=175 Number of Objects=17 Vehicle_count=11 Person_count=5
# Frame Number=176 Number of Objects=18 Vehicle_count=11 Person_count=6
# Frame Number=177 Number of Objects=22 Vehicle_count=14 Person_count=7
# Frame Number=178 Number of Objects=24 Vehicle_count=15 Person_count=8
# Frame Number=179 Number of Objects=17 Vehicle_count=11 Person_count=6
# Frame Number=180 Number of Objects=20 Vehicle_count=13 Person_count=6
# Frame Number=181 Number of Objects=19 Vehicle_count=13 Person_count=5
# Frame Number=182 Number of Objects=16 Vehicle_count=11 Person_count=4
# Frame Number=183 Number of Objects=16 Vehicle_count=10 Person_count=5
# Frame Number=184 Number of Objects=19 Vehicle_count=13 Person_count=5
# Frame Number=185 Number of Objects=14 Vehicle_count=9 Person_count=4
# Frame Number=186 Number of Objects=19 Vehicle_count=12 Person_count=6
# Frame Number=187 Number of Objects=20 Vehicle_count=11 Person_count=8
# Frame Number=188 Number of Objects=20 Vehicle_count=11 Person_count=8
# Frame Number=189 Number of Objects=18 Vehicle_count=11 Person_count=6
# Frame Number=190 Number of Objects=18 Vehicle_count=9 Person_count=7
# Frame Number=191 Number of Objects=21 Vehicle_count=10 Person_count=8
# Frame Number=192 Number of Objects=19 Vehicle_count=10 Person_count=8
# Frame Number=193 Number of Objects=21 Vehicle_count=12 Person_count=8
# Frame Number=194 Number of Objects=17 Vehicle_count=9 Person_count=8
# Frame Number=195 Number of Objects=16 Vehicle_count=10 Person_count=6
# Frame Number=196 Number of Objects=19 Vehicle_count=13 Person_count=5
# Frame Number=197 Number of Objects=18 Vehicle_count=11 Person_count=7
# Frame Number=198 Number of Objects=15 Vehicle_count=10 Person_count=5
# Frame Number=199 Number of Objects=23 Vehicle_count=14 Person_count=8
# Frame Number=200 Number of Objects=19 Vehicle_count=10 Person_count=7
# Frame Number=201 Number of Objects=18 Vehicle_count=9 Person_count=8
# Frame Number=202 Number of Objects=16 Vehicle_count=10 Person_count=6
# Frame Number=203 Number of Objects=17 Vehicle_count=9 Person_count=6
# Frame Number=204 Number of Objects=17 Vehicle_count=10 Person_count=7
# Frame Number=205 Number of Objects=20 Vehicle_count=13 Person_count=6
# Frame Number=206 Number of Objects=23 Vehicle_count=14 Person_count=8
# Frame Number=207 Number of Objects=20 Vehicle_count=12 Person_count=7
# Frame Number=208 Number of Objects=21 Vehicle_count=12 Person_count=9
# Frame Number=209 Number of Objects=21 Vehicle_count=11 Person_count=10
# Frame Number=210 Number of Objects=24 Vehicle_count=14 Person_count=10
# Frame Number=211 Number of Objects=24 Vehicle_count=18 Person_count=6
# Frame Number=212 Number of Objects=23 Vehicle_count=16 Person_count=7
# Frame Number=213 Number of Objects=24 Vehicle_count=18 Person_count=6
# Frame Number=214 Number of Objects=20 Vehicle_count=15 Person_count=5
# Frame Number=215 Number of Objects=23 Vehicle_count=17 Person_count=6
# Frame Number=216 Number of Objects=23 Vehicle_count=18 Person_count=5
# Frame Number=217 Number of Objects=21 Vehicle_count=16 Person_count=5
# Frame Number=218 Number of Objects=19 Vehicle_count=13 Person_count=4
# Frame Number=219 Number of Objects=21 Vehicle_count=16 Person_count=4
# Frame Number=220 Number of Objects=20 Vehicle_count=16 Person_count=4
# Frame Number=221 Number of Objects=17 Vehicle_count=13 Person_count=3
# Frame Number=222 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=223 Number of Objects=19 Vehicle_count=16 Person_count=3
# Frame Number=224 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=225 Number of Objects=21 Vehicle_count=17 Person_count=4
# Frame Number=226 Number of Objects=20 Vehicle_count=16 Person_count=4
# Frame Number=227 Number of Objects=21 Vehicle_count=18 Person_count=3
# Frame Number=228 Number of Objects=17 Vehicle_count=13 Person_count=4
# Frame Number=229 Number of Objects=20 Vehicle_count=14 Person_count=5
# Frame Number=230 Number of Objects=17 Vehicle_count=14 Person_count=3
# Frame Number=231 Number of Objects=20 Vehicle_count=16 Person_count=4
# Frame Number=232 Number of Objects=21 Vehicle_count=18 Person_count=3
# Frame Number=233 Number of Objects=20 Vehicle_count=15 Person_count=3
# Frame Number=234 Number of Objects=18 Vehicle_count=14 Person_count=4
# Frame Number=235 Number of Objects=19 Vehicle_count=16 Person_count=3
# Frame Number=236 Number of Objects=24 Vehicle_count=19 Person_count=3
# Frame Number=237 Number of Objects=19 Vehicle_count=15 Person_count=2
# Frame Number=238 Number of Objects=21 Vehicle_count=18 Person_count=2
# Frame Number=239 Number of Objects=20 Vehicle_count=16 Person_count=3
# Frame Number=240 Number of Objects=20 Vehicle_count=16 Person_count=3
# Frame Number=241 Number of Objects=18 Vehicle_count=13 Person_count=3
# Frame Number=242 Number of Objects=17 Vehicle_count=14 Person_count=3
# Frame Number=243 Number of Objects=18 Vehicle_count=13 Person_count=3
# Frame Number=244 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=245 Number of Objects=17 Vehicle_count=14 Person_count=3
# Frame Number=246 Number of Objects=17 Vehicle_count=12 Person_count=5
# Frame Number=247 Number of Objects=20 Vehicle_count=15 Person_count=5
# Frame Number=248 Number of Objects=23 Vehicle_count=18 Person_count=5
# Frame Number=249 Number of Objects=22 Vehicle_count=18 Person_count=4
# Frame Number=250 Number of Objects=20 Vehicle_count=14 Person_count=5
# Frame Number=251 Number of Objects=20 Vehicle_count=15 Person_count=5
# Frame Number=252 Number of Objects=17 Vehicle_count=12 Person_count=5
# Frame Number=253 Number of Objects=17 Vehicle_count=14 Person_count=3
# Frame Number=254 Number of Objects=16 Vehicle_count=12 Person_count=3
# Frame Number=255 Number of Objects=16 Vehicle_count=13 Person_count=3
# Frame Number=256 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=257 Number of Objects=16 Vehicle_count=13 Person_count=3
# Frame Number=258 Number of Objects=21 Vehicle_count=18 Person_count=3
# Frame Number=259 Number of Objects=23 Vehicle_count=20 Person_count=3
# Frame Number=260 Number of Objects=23 Vehicle_count=20 Person_count=3
# Frame Number=261 Number of Objects=23 Vehicle_count=19 Person_count=4
# Frame Number=262 Number of Objects=21 Vehicle_count=17 Person_count=4
# Frame Number=263 Number of Objects=20 Vehicle_count=17 Person_count=3
# Frame Number=264 Number of Objects=21 Vehicle_count=17 Person_count=4
# Frame Number=265 Number of Objects=21 Vehicle_count=18 Person_count=3
# Frame Number=266 Number of Objects=19 Vehicle_count=15 Person_count=4
# Frame Number=267 Number of Objects=23 Vehicle_count=20 Person_count=3
# Frame Number=268 Number of Objects=24 Vehicle_count=20 Person_count=4
# Frame Number=269 Number of Objects=24 Vehicle_count=20 Person_count=4
# Frame Number=270 Number of Objects=24 Vehicle_count=20 Person_count=4
# Frame Number=271 Number of Objects=24 Vehicle_count=20 Person_count=4
# Frame Number=272 Number of Objects=24 Vehicle_count=20 Person_count=4
# Frame Number=273 Number of Objects=23 Vehicle_count=20 Person_count=3
# Frame Number=274 Number of Objects=22 Vehicle_count=19 Person_count=3
# Frame Number=275 Number of Objects=19 Vehicle_count=15 Person_count=4
# Frame Number=276 Number of Objects=19 Vehicle_count=16 Person_count=3
# Frame Number=277 Number of Objects=23 Vehicle_count=18 Person_count=5
# Frame Number=278 Number of Objects=20 Vehicle_count=16 Person_count=4
# Frame Number=279 Number of Objects=20 Vehicle_count=16 Person_count=4
# Frame Number=280 Number of Objects=23 Vehicle_count=18 Person_count=5
# Frame Number=281 Number of Objects=25 Vehicle_count=20 Person_count=5
# Frame Number=282 Number of Objects=20 Vehicle_count=16 Person_count=4
# Frame Number=283 Number of Objects=22 Vehicle_count=18 Person_count=4
# Frame Number=284 Number of Objects=22 Vehicle_count=18 Person_count=4
# Frame Number=285 Number of Objects=22 Vehicle_count=18 Person_count=4
# Frame Number=286 Number of Objects=24 Vehicle_count=20 Person_count=4
# Frame Number=287 Number of Objects=24 Vehicle_count=20 Person_count=4
# Frame Number=288 Number of Objects=25 Vehicle_count=20 Person_count=5
# Frame Number=289 Number of Objects=21 Vehicle_count=16 Person_count=5
# Frame Number=290 Number of Objects=21 Vehicle_count=16 Person_count=5
# Frame Number=291 Number of Objects=23 Vehicle_count=18 Person_count=5
# Frame Number=292 Number of Objects=23 Vehicle_count=18 Person_count=5
# Frame Number=293 Number of Objects=20 Vehicle_count=15 Person_count=4
# Frame Number=294 Number of Objects=19 Vehicle_count=15 Person_count=4
# Frame Number=295 Number of Objects=24 Vehicle_count=18 Person_count=5
# Frame Number=296 Number of Objects=24 Vehicle_count=19 Person_count=5
# Frame Number=297 Number of Objects=26 Vehicle_count=20 Person_count=4
# Frame Number=298 Number of Objects=26 Vehicle_count=19 Person_count=5
# Frame Number=299 Number of Objects=17 Vehicle_count=12 Person_count=4
# Frame Number=300 Number of Objects=20 Vehicle_count=15 Person_count=4
# Frame Number=301 Number of Objects=20 Vehicle_count=16 Person_count=4
# Frame Number=302 Number of Objects=18 Vehicle_count=14 Person_count=4
# Frame Number=303 Number of Objects=15 Vehicle_count=11 Person_count=4
# Frame Number=304 Number of Objects=19 Vehicle_count=14 Person_count=5
# Frame Number=305 Number of Objects=19 Vehicle_count=14 Person_count=5
# Frame Number=306 Number of Objects=18 Vehicle_count=13 Person_count=5
# Frame Number=307 Number of Objects=19 Vehicle_count=14 Person_count=5
# Frame Number=308 Number of Objects=19 Vehicle_count=14 Person_count=5
# Frame Number=309 Number of Objects=21 Vehicle_count=14 Person_count=5
# Frame Number=310 Number of Objects=18 Vehicle_count=13 Person_count=5
# Frame Number=311 Number of Objects=17 Vehicle_count=11 Person_count=6
# Frame Number=312 Number of Objects=18 Vehicle_count=13 Person_count=5
# Frame Number=313 Number of Objects=18 Vehicle_count=11 Person_count=7
# Frame Number=314 Number of Objects=19 Vehicle_count=13 Person_count=6
# Frame Number=315 Number of Objects=13 Vehicle_count=8 Person_count=5
# Frame Number=316 Number of Objects=18 Vehicle_count=12 Person_count=6
# Frame Number=317 Number of Objects=18 Vehicle_count=13 Person_count=5
# Frame Number=318 Number of Objects=19 Vehicle_count=13 Person_count=6
# Frame Number=319 Number of Objects=20 Vehicle_count=15 Person_count=5
# Frame Number=320 Number of Objects=23 Vehicle_count=19 Person_count=4
# Frame Number=321 Number of Objects=22 Vehicle_count=17 Person_count=5
# Frame Number=322 Number of Objects=21 Vehicle_count=16 Person_count=5
# Frame Number=323 Number of Objects=22 Vehicle_count=16 Person_count=6
# Frame Number=324 Number of Objects=24 Vehicle_count=18 Person_count=6
# Frame Number=325 Number of Objects=21 Vehicle_count=14 Person_count=7
# Frame Number=326 Number of Objects=21 Vehicle_count=15 Person_count=6
# Frame Number=327 Number of Objects=24 Vehicle_count=19 Person_count=5
# Frame Number=328 Number of Objects=22 Vehicle_count=17 Person_count=5
# Frame Number=329 Number of Objects=22 Vehicle_count=17 Person_count=5
# Frame Number=330 Number of Objects=24 Vehicle_count=19 Person_count=5
# Frame Number=331 Number of Objects=25 Vehicle_count=19 Person_count=6
# Frame Number=332 Number of Objects=22 Vehicle_count=17 Person_count=5
# Frame Number=333 Number of Objects=24 Vehicle_count=18 Person_count=6
# Frame Number=334 Number of Objects=22 Vehicle_count=17 Person_count=5
# Frame Number=335 Number of Objects=26 Vehicle_count=20 Person_count=6
# Frame Number=336 Number of Objects=25 Vehicle_count=20 Person_count=5
# Frame Number=337 Number of Objects=26 Vehicle_count=20 Person_count=6
# Frame Number=338 Number of Objects=26 Vehicle_count=20 Person_count=6
# Frame Number=339 Number of Objects=25 Vehicle_count=20 Person_count=5
# Frame Number=340 Number of Objects=22 Vehicle_count=16 Person_count=6
# Frame Number=341 Number of Objects=24 Vehicle_count=19 Person_count=5
# Frame Number=342 Number of Objects=25 Vehicle_count=20 Person_count=5
# Frame Number=343 Number of Objects=27 Vehicle_count=20 Person_count=7
# Frame Number=344 Number of Objects=27 Vehicle_count=20 Person_count=7
# Frame Number=345 Number of Objects=22 Vehicle_count=16 Person_count=6
# Frame Number=346 Number of Objects=19 Vehicle_count=14 Person_count=5
# Frame Number=347 Number of Objects=21 Vehicle_count=15 Person_count=6
# Frame Number=348 Number of Objects=22 Vehicle_count=16 Person_count=6
# Frame Number=349 Number of Objects=21 Vehicle_count=17 Person_count=4
# Frame Number=350 Number of Objects=21 Vehicle_count=16 Person_count=5
# Frame Number=351 Number of Objects=19 Vehicle_count=13 Person_count=6
# Frame Number=352 Number of Objects=23 Vehicle_count=17 Person_count=6
# Frame Number=353 Number of Objects=22 Vehicle_count=16 Person_count=6
# Frame Number=354 Number of Objects=23 Vehicle_count=16 Person_count=7
# Frame Number=355 Number of Objects=22 Vehicle_count=16 Person_count=6
# Frame Number=356 Number of Objects=22 Vehicle_count=15 Person_count=7
# Frame Number=357 Number of Objects=19 Vehicle_count=14 Person_count=5
# Frame Number=358 Number of Objects=21 Vehicle_count=16 Person_count=5
# Frame Number=359 Number of Objects=20 Vehicle_count=15 Person_count=5
# Frame Number=360 Number of Objects=19 Vehicle_count=14 Person_count=5
# Frame Number=361 Number of Objects=18 Vehicle_count=14 Person_count=4
# Frame Number=362 Number of Objects=19 Vehicle_count=14 Person_count=5
# Frame Number=363 Number of Objects=25 Vehicle_count=20 Person_count=5
# Frame Number=364 Number of Objects=25 Vehicle_count=20 Person_count=5
# Frame Number=365 Number of Objects=23 Vehicle_count=18 Person_count=5
# Frame Number=366 Number of Objects=20 Vehicle_count=15 Person_count=5
# Frame Number=367 Number of Objects=20 Vehicle_count=15 Person_count=5
# Frame Number=368 Number of Objects=21 Vehicle_count=16 Person_count=5
# Frame Number=369 Number of Objects=19 Vehicle_count=14 Person_count=5
# Frame Number=370 Number of Objects=19 Vehicle_count=14 Person_count=5
# Frame Number=371 Number of Objects=22 Vehicle_count=16 Person_count=6
# Frame Number=372 Number of Objects=21 Vehicle_count=16 Person_count=5
# Frame Number=373 Number of Objects=27 Vehicle_count=20 Person_count=7
# Frame Number=374 Number of Objects=23 Vehicle_count=18 Person_count=5
# Frame Number=375 Number of Objects=20 Vehicle_count=15 Person_count=5
# Frame Number=376 Number of Objects=24 Vehicle_count=19 Person_count=5
# Frame Number=377 Number of Objects=25 Vehicle_count=20 Person_count=5
# Frame Number=378 Number of Objects=25 Vehicle_count=20 Person_count=5
# Frame Number=379 Number of Objects=22 Vehicle_count=17 Person_count=5
# Frame Number=380 Number of Objects=24 Vehicle_count=19 Person_count=5
# Frame Number=381 Number of Objects=22 Vehicle_count=15 Person_count=7
# Frame Number=382 Number of Objects=24 Vehicle_count=18 Person_count=6
# Frame Number=383 Number of Objects=24 Vehicle_count=18 Person_count=6
# Frame Number=384 Number of Objects=24 Vehicle_count=17 Person_count=6
# Frame Number=385 Number of Objects=27 Vehicle_count=19 Person_count=6
# Frame Number=386 Number of Objects=25 Vehicle_count=15 Person_count=7
# Frame Number=387 Number of Objects=30 Vehicle_count=20 Person_count=6
# Frame Number=388 Number of Objects=28 Vehicle_count=18 Person_count=7
# Frame Number=389 Number of Objects=29 Vehicle_count=20 Person_count=7
# Frame Number=390 Number of Objects=31 Vehicle_count=20 Person_count=8
# Frame Number=391 Number of Objects=30 Vehicle_count=20 Person_count=7
# Frame Number=392 Number of Objects=31 Vehicle_count=20 Person_count=7
# Frame Number=393 Number of Objects=27 Vehicle_count=20 Person_count=6
# Frame Number=394 Number of Objects=26 Vehicle_count=17 Person_count=6
# Frame Number=395 Number of Objects=26 Vehicle_count=20 Person_count=5
# Frame Number=396 Number of Objects=26 Vehicle_count=19 Person_count=7
# Frame Number=397 Number of Objects=29 Vehicle_count=20 Person_count=7
# Frame Number=398 Number of Objects=24 Vehicle_count=17 Person_count=6
# Frame Number=399 Number of Objects=27 Vehicle_count=18 Person_count=6
# Frame Number=400 Number of Objects=26 Vehicle_count=16 Person_count=7
# Frame Number=401 Number of Objects=22 Vehicle_count=14 Person_count=6
# Frame Number=402 Number of Objects=18 Vehicle_count=11 Person_count=5
# Frame Number=403 Number of Objects=20 Vehicle_count=13 Person_count=5
# Frame Number=404 Number of Objects=24 Vehicle_count=16 Person_count=6
# Frame Number=405 Number of Objects=25 Vehicle_count=17 Person_count=6
# Frame Number=406 Number of Objects=27 Vehicle_count=19 Person_count=6
# Frame Number=407 Number of Objects=25 Vehicle_count=17 Person_count=5
# Frame Number=408 Number of Objects=23 Vehicle_count=15 Person_count=5
# Frame Number=409 Number of Objects=25 Vehicle_count=17 Person_count=5
# Frame Number=410 Number of Objects=27 Vehicle_count=19 Person_count=5
# Frame Number=411 Number of Objects=27 Vehicle_count=20 Person_count=5
# Frame Number=412 Number of Objects=25 Vehicle_count=18 Person_count=6
# Frame Number=413 Number of Objects=28 Vehicle_count=19 Person_count=5
# Frame Number=414 Number of Objects=25 Vehicle_count=17 Person_count=5
# Frame Number=415 Number of Objects=29 Vehicle_count=20 Person_count=5
# Frame Number=416 Number of Objects=28 Vehicle_count=20 Person_count=5
# Frame Number=417 Number of Objects=28 Vehicle_count=20 Person_count=5
# Frame Number=418 Number of Objects=28 Vehicle_count=20 Person_count=5
# Frame Number=419 Number of Objects=25 Vehicle_count=18 Person_count=5
# Frame Number=420 Number of Objects=27 Vehicle_count=20 Person_count=5
# Frame Number=421 Number of Objects=27 Vehicle_count=20 Person_count=5
# Frame Number=422 Number of Objects=27 Vehicle_count=20 Person_count=5
# Frame Number=423 Number of Objects=28 Vehicle_count=20 Person_count=6
# Frame Number=424 Number of Objects=28 Vehicle_count=20 Person_count=6
# Frame Number=425 Number of Objects=28 Vehicle_count=20 Person_count=6
# Frame Number=426 Number of Objects=28 Vehicle_count=20 Person_count=6
# Frame Number=427 Number of Objects=28 Vehicle_count=20 Person_count=5
# Frame Number=428 Number of Objects=27 Vehicle_count=20 Person_count=5
# Frame Number=429 Number of Objects=26 Vehicle_count=19 Person_count=5
# Frame Number=430 Number of Objects=23 Vehicle_count=16 Person_count=5
# Frame Number=431 Number of Objects=25 Vehicle_count=18 Person_count=5
# Frame Number=432 Number of Objects=25 Vehicle_count=18 Person_count=5
# Frame Number=433 Number of Objects=25 Vehicle_count=18 Person_count=5
# Frame Number=434 Number of Objects=23 Vehicle_count=16 Person_count=5
# Frame Number=435 Number of Objects=26 Vehicle_count=19 Person_count=5
# Frame Number=436 Number of Objects=28 Vehicle_count=20 Person_count=6
# Frame Number=437 Number of Objects=24 Vehicle_count=17 Person_count=5
# Frame Number=438 Number of Objects=27 Vehicle_count=20 Person_count=5
# Frame Number=439 Number of Objects=27 Vehicle_count=20 Person_count=5
# Frame Number=440 Number of Objects=27 Vehicle_count=20 Person_count=5
# Frame Number=441 Number of Objects=25 Vehicle_count=20 Person_count=4
# Frame Number=442 Number of Objects=25 Vehicle_count=19 Person_count=4
# Frame Number=443 Number of Objects=25 Vehicle_count=20 Person_count=4
# Frame Number=444 Number of Objects=22 Vehicle_count=18 Person_count=3
# Frame Number=445 Number of Objects=23 Vehicle_count=15 Person_count=6
# Frame Number=446 Number of Objects=27 Vehicle_count=20 Person_count=6
# Frame Number=447 Number of Objects=21 Vehicle_count=15 Person_count=5
# Frame Number=448 Number of Objects=26 Vehicle_count=20 Person_count=4
# Frame Number=449 Number of Objects=23 Vehicle_count=19 Person_count=4
# Frame Number=450 Number of Objects=21 Vehicle_count=18 Person_count=3
# Frame Number=451 Number of Objects=22 Vehicle_count=20 Person_count=2
# Frame Number=452 Number of Objects=23 Vehicle_count=20 Person_count=3
# Frame Number=453 Number of Objects=21 Vehicle_count=19 Person_count=2
# Frame Number=454 Number of Objects=25 Vehicle_count=20 Person_count=5
# Frame Number=455 Number of Objects=25 Vehicle_count=20 Person_count=4
# Frame Number=456 Number of Objects=23 Vehicle_count=20 Person_count=3
# Frame Number=457 Number of Objects=23 Vehicle_count=20 Person_count=3
# Frame Number=458 Number of Objects=21 Vehicle_count=18 Person_count=3
# Frame Number=459 Number of Objects=22 Vehicle_count=20 Person_count=2
# Frame Number=460 Number of Objects=24 Vehicle_count=20 Person_count=4
# Frame Number=461 Number of Objects=24 Vehicle_count=20 Person_count=3
# Frame Number=462 Number of Objects=26 Vehicle_count=20 Person_count=4
# Frame Number=463 Number of Objects=26 Vehicle_count=20 Person_count=4
# Frame Number=464 Number of Objects=25 Vehicle_count=19 Person_count=4
# Frame Number=465 Number of Objects=23 Vehicle_count=18 Person_count=4
# Frame Number=466 Number of Objects=25 Vehicle_count=20 Person_count=4
# Frame Number=467 Number of Objects=23 Vehicle_count=20 Person_count=2
# Frame Number=468 Number of Objects=23 Vehicle_count=20 Person_count=2
# Frame Number=469 Number of Objects=24 Vehicle_count=20 Person_count=3
# Frame Number=470 Number of Objects=23 Vehicle_count=20 Person_count=3
# Frame Number=471 Number of Objects=24 Vehicle_count=20 Person_count=4
# Frame Number=472 Number of Objects=23 Vehicle_count=20 Person_count=3
# Frame Number=473 Number of Objects=23 Vehicle_count=20 Person_count=3
# Frame Number=474 Number of Objects=20 Vehicle_count=18 Person_count=2
# Frame Number=475 Number of Objects=21 Vehicle_count=18 Person_count=3
# Frame Number=476 Number of Objects=20 Vehicle_count=17 Person_count=3
# Frame Number=477 Number of Objects=20 Vehicle_count=18 Person_count=2
# Frame Number=478 Number of Objects=20 Vehicle_count=17 Person_count=2
# Frame Number=479 Number of Objects=21 Vehicle_count=18 Person_count=2
# Frame Number=480 Number of Objects=21 Vehicle_count=18 Person_count=2
# Frame Number=481 Number of Objects=21 Vehicle_count=18 Person_count=2
# Frame Number=482 Number of Objects=23 Vehicle_count=19 Person_count=3
# Frame Number=483 Number of Objects=24 Vehicle_count=20 Person_count=3
# Frame Number=484 Number of Objects=23 Vehicle_count=19 Person_count=4
# Frame Number=485 Number of Objects=22 Vehicle_count=19 Person_count=3
# Frame Number=486 Number of Objects=22 Vehicle_count=19 Person_count=3
# Frame Number=487 Number of Objects=18 Vehicle_count=15 Person_count=3
# Frame Number=488 Number of Objects=19 Vehicle_count=16 Person_count=3
# Frame Number=489 Number of Objects=20 Vehicle_count=17 Person_count=3
# Frame Number=490 Number of Objects=22 Vehicle_count=19 Person_count=3
# Frame Number=491 Number of Objects=19 Vehicle_count=15 Person_count=4
# Frame Number=492 Number of Objects=18 Vehicle_count=15 Person_count=3
# Frame Number=493 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=494 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=495 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=496 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=497 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=498 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=499 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=500 Number of Objects=18 Vehicle_count=16 Person_count=2
# Frame Number=501 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=502 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=503 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=504 Number of Objects=18 Vehicle_count=17 Person_count=1
# Frame Number=505 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=506 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=507 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=508 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=509 Number of Objects=19 Vehicle_count=17 Person_count=2
# Frame Number=510 Number of Objects=17 Vehicle_count=14 Person_count=3
# Frame Number=511 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=512 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=513 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=514 Number of Objects=12 Vehicle_count=9 Person_count=3
# Frame Number=515 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=516 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=517 Number of Objects=12 Vehicle_count=9 Person_count=3
# Frame Number=518 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=519 Number of Objects=8 Vehicle_count=6 Person_count=2
# Frame Number=520 Number of Objects=12 Vehicle_count=9 Person_count=3
# Frame Number=521 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=522 Number of Objects=13 Vehicle_count=9 Person_count=4
# Frame Number=523 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=524 Number of Objects=11 Vehicle_count=8 Person_count=3
# Frame Number=525 Number of Objects=12 Vehicle_count=8 Person_count=4
# Frame Number=526 Number of Objects=8 Vehicle_count=6 Person_count=2
# Frame Number=527 Number of Objects=8 Vehicle_count=6 Person_count=2
# Frame Number=528 Number of Objects=8 Vehicle_count=7 Person_count=1
# Frame Number=529 Number of Objects=9 Vehicle_count=8 Person_count=1
# Frame Number=530 Number of Objects=11 Vehicle_count=10 Person_count=1
# Frame Number=531 Number of Objects=10 Vehicle_count=9 Person_count=1
# Frame Number=532 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=533 Number of Objects=12 Vehicle_count=11 Person_count=1
# Frame Number=534 Number of Objects=14 Vehicle_count=13 Person_count=1
# Frame Number=535 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=536 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=537 Number of Objects=15 Vehicle_count=14 Person_count=1
# Frame Number=538 Number of Objects=13 Vehicle_count=12 Person_count=1
# Frame Number=539 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=540 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=541 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=542 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=543 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=544 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=545 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=546 Number of Objects=12 Vehicle_count=11 Person_count=1
# Frame Number=547 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=548 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=549 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=550 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=551 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=552 Number of Objects=17 Vehicle_count=14 Person_count=3
# Frame Number=553 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=554 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=555 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=556 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=557 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=558 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=559 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=560 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=561 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=562 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=563 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=564 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=565 Number of Objects=18 Vehicle_count=15 Person_count=3
# Frame Number=566 Number of Objects=19 Vehicle_count=16 Person_count=3
# Frame Number=567 Number of Objects=19 Vehicle_count=15 Person_count=4
# Frame Number=568 Number of Objects=21 Vehicle_count=17 Person_count=4
# Frame Number=569 Number of Objects=18 Vehicle_count=14 Person_count=4
# Frame Number=570 Number of Objects=17 Vehicle_count=13 Person_count=4
# Frame Number=571 Number of Objects=16 Vehicle_count=11 Person_count=5
# Frame Number=572 Number of Objects=14 Vehicle_count=10 Person_count=4
# Frame Number=573 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=574 Number of Objects=12 Vehicle_count=9 Person_count=3
# Frame Number=575 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=576 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=577 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=578 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=579 Number of Objects=16 Vehicle_count=12 Person_count=4
# Frame Number=580 Number of Objects=18 Vehicle_count=14 Person_count=4
# Frame Number=581 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=582 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=583 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=584 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=585 Number of Objects=16 Vehicle_count=13 Person_count=3
# Frame Number=586 Number of Objects=16 Vehicle_count=13 Person_count=3
# Frame Number=587 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=588 Number of Objects=16 Vehicle_count=13 Person_count=3
# Frame Number=589 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=590 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=591 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=592 Number of Objects=17 Vehicle_count=14 Person_count=3
# Frame Number=593 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=594 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=595 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=596 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=597 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=598 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=599 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=600 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=601 Number of Objects=10 Vehicle_count=8 Person_count=2
# Frame Number=602 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=603 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=604 Number of Objects=15 Vehicle_count=11 Person_count=4
# Frame Number=605 Number of Objects=15 Vehicle_count=11 Person_count=4
# Frame Number=606 Number of Objects=15 Vehicle_count=11 Person_count=4
# Frame Number=607 Number of Objects=15 Vehicle_count=11 Person_count=4
# Frame Number=608 Number of Objects=15 Vehicle_count=11 Person_count=4
# Frame Number=609 Number of Objects=16 Vehicle_count=12 Person_count=4
# Frame Number=610 Number of Objects=12 Vehicle_count=8 Person_count=4
# Frame Number=611 Number of Objects=12 Vehicle_count=8 Person_count=4
# ...
# Frame Number=1217 Number of Objects=17 Vehicle_count=14 Person_count=3
# Frame Number=1218 Number of Objects=17 Vehicle_count=14 Person_count=3
# Frame Number=1219 Number of Objects=17 Vehicle_count=14 Person_count=3
# Frame Number=1220 Number of Objects=17 Vehicle_count=14 Person_count=3
# Frame Number=1221 Number of Objects=19 Vehicle_count=16 Person_count=3
# Frame Number=1222 Number of Objects=16 Vehicle_count=13 Person_count=3
# Frame Number=1223 Number of Objects=18 Vehicle_count=15 Person_count=3
# Frame Number=1224 Number of Objects=18 Vehicle_count=15 Person_count=3
# Frame Number=1225 Number of Objects=17 Vehicle_count=14 Person_count=3
# Frame Number=1226 Number of Objects=18 Vehicle_count=15 Person_count=3
# Frame Number=1227 Number of Objects=18 Vehicle_count=15 Person_count=3
# Frame Number=1228 Number of Objects=21 Vehicle_count=18 Person_count=3
# Frame Number=1229 Number of Objects=23 Vehicle_count=20 Person_count=3
# Frame Number=1230 Number of Objects=23 Vehicle_count=20 Person_count=3
# Frame Number=1231 Number of Objects=22 Vehicle_count=19 Person_count=3
# Frame Number=1232 Number of Objects=21 Vehicle_count=18 Person_count=3
# Frame Number=1233 Number of Objects=20 Vehicle_count=17 Person_count=3
# Frame Number=1234 Number of Objects=19 Vehicle_count=16 Person_count=3
# Frame Number=1235 Number of Objects=20 Vehicle_count=17 Person_count=3
# Frame Number=1236 Number of Objects=17 Vehicle_count=13 Person_count=4
# Frame Number=1237 Number of Objects=17 Vehicle_count=13 Person_count=4
# Frame Number=1238 Number of Objects=16 Vehicle_count=12 Person_count=4
# Frame Number=1239 Number of Objects=16 Vehicle_count=12 Person_count=4
# Frame Number=1240 Number of Objects=12 Vehicle_count=8 Person_count=4
# Frame Number=1241 Number of Objects=13 Vehicle_count=9 Person_count=4
# Frame Number=1242 Number of Objects=11 Vehicle_count=7 Person_count=4
# Frame Number=1243 Number of Objects=12 Vehicle_count=8 Person_count=4
# Frame Number=1244 Number of Objects=14 Vehicle_count=10 Person_count=4
# Frame Number=1245 Number of Objects=13 Vehicle_count=9 Person_count=4
# Frame Number=1246 Number of Objects=12 Vehicle_count=8 Person_count=4
# Frame Number=1247 Number of Objects=11 Vehicle_count=7 Person_count=4
# Frame Number=1248 Number of Objects=11 Vehicle_count=7 Person_count=4
# Frame Number=1249 Number of Objects=12 Vehicle_count=9 Person_count=3
# Frame Number=1250 Number of Objects=12 Vehicle_count=8 Person_count=4
# Frame Number=1251 Number of Objects=13 Vehicle_count=9 Person_count=4
# Frame Number=1252 Number of Objects=13 Vehicle_count=9 Person_count=4
# Frame Number=1253 Number of Objects=11 Vehicle_count=8 Person_count=3
# Frame Number=1254 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=1255 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=1256 Number of Objects=12 Vehicle_count=9 Person_count=3
# Frame Number=1257 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=1258 Number of Objects=16 Vehicle_count=13 Person_count=3
# Frame Number=1259 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=1260 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=1261 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1262 Number of Objects=16 Vehicle_count=13 Person_count=3
# Frame Number=1263 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=1264 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=1265 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=1266 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=1267 Number of Objects=13 Vehicle_count=10 Person_count=3
# Frame Number=1268 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=1269 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=1270 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=1271 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=1272 Number of Objects=16 Vehicle_count=13 Person_count=3
# Frame Number=1273 Number of Objects=16 Vehicle_count=13 Person_count=3
# Frame Number=1274 Number of Objects=16 Vehicle_count=13 Person_count=3
# Frame Number=1275 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=1276 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=1277 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=1278 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=1279 Number of Objects=16 Vehicle_count=13 Person_count=3
# Frame Number=1280 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1281 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=1282 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1283 Number of Objects=14 Vehicle_count=11 Person_count=3
# Frame Number=1284 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1285 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1286 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=1287 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=1288 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1289 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1290 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1291 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1292 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1293 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1294 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1295 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1296 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1297 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=1298 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1299 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1300 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1301 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1302 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1303 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1304 Number of Objects=12 Vehicle_count=9 Person_count=3
# Frame Number=1305 Number of Objects=10 Vehicle_count=8 Person_count=2
# Frame Number=1306 Number of Objects=10 Vehicle_count=8 Person_count=2
# Frame Number=1307 Number of Objects=10 Vehicle_count=8 Person_count=2
# Frame Number=1308 Number of Objects=10 Vehicle_count=8 Person_count=2
# Frame Number=1309 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=1310 Number of Objects=9 Vehicle_count=7 Person_count=2
# Frame Number=1311 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=1312 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=1313 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1314 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1315 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1316 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=1317 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=1318 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1319 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1320 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=1321 Number of Objects=20 Vehicle_count=18 Person_count=2
# Frame Number=1322 Number of Objects=19 Vehicle_count=17 Person_count=2
# Frame Number=1323 Number of Objects=18 Vehicle_count=16 Person_count=2
# Frame Number=1324 Number of Objects=22 Vehicle_count=20 Person_count=2
# Frame Number=1325 Number of Objects=21 Vehicle_count=19 Person_count=2
# Frame Number=1326 Number of Objects=22 Vehicle_count=20 Person_count=2
# Frame Number=1327 Number of Objects=22 Vehicle_count=20 Person_count=2
# Frame Number=1328 Number of Objects=20 Vehicle_count=18 Person_count=2
# Frame Number=1329 Number of Objects=21 Vehicle_count=19 Person_count=2
# Frame Number=1330 Number of Objects=20 Vehicle_count=18 Person_count=2
# Frame Number=1331 Number of Objects=20 Vehicle_count=18 Person_count=2
# Frame Number=1332 Number of Objects=19 Vehicle_count=17 Person_count=2
# Frame Number=1333 Number of Objects=22 Vehicle_count=20 Person_count=2
# Frame Number=1334 Number of Objects=21 Vehicle_count=19 Person_count=2
# Frame Number=1335 Number of Objects=19 Vehicle_count=17 Person_count=2
# Frame Number=1336 Number of Objects=19 Vehicle_count=17 Person_count=2
# Frame Number=1337 Number of Objects=20 Vehicle_count=18 Person_count=2
# Frame Number=1338 Number of Objects=22 Vehicle_count=20 Person_count=2
# Frame Number=1339 Number of Objects=21 Vehicle_count=19 Person_count=2
# Frame Number=1340 Number of Objects=18 Vehicle_count=16 Person_count=2
# Frame Number=1341 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1342 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=1343 Number of Objects=18 Vehicle_count=16 Person_count=2
# Frame Number=1344 Number of Objects=22 Vehicle_count=20 Person_count=2
# Frame Number=1345 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=1346 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=1347 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1348 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1349 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1350 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1351 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=1352 Number of Objects=20 Vehicle_count=18 Person_count=2
# Frame Number=1353 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1354 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1355 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1356 Number of Objects=22 Vehicle_count=20 Person_count=2
# Frame Number=1357 Number of Objects=18 Vehicle_count=16 Person_count=2
# Frame Number=1358 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=1359 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1360 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1361 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1362 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1363 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1364 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1365 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1366 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1367 Number of Objects=21 Vehicle_count=19 Person_count=2
# Frame Number=1368 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=1369 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=1370 Number of Objects=19 Vehicle_count=17 Person_count=2
# Frame Number=1371 Number of Objects=19 Vehicle_count=17 Person_count=2
# Frame Number=1372 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1373 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1374 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1375 Number of Objects=19 Vehicle_count=17 Person_count=2
# Frame Number=1376 Number of Objects=21 Vehicle_count=19 Person_count=2
# Frame Number=1377 Number of Objects=18 Vehicle_count=16 Person_count=2
# Frame Number=1378 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1379 Number of Objects=19 Vehicle_count=17 Person_count=2
# Frame Number=1380 Number of Objects=19 Vehicle_count=17 Person_count=2
# Frame Number=1381 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1382 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1383 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=1384 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1385 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1386 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1387 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1388 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1389 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1390 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1391 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1392 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1393 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1394 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1395 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1396 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1397 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1398 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=1399 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=1400 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1401 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1402 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1403 Number of Objects=14 Vehicle_count=13 Person_count=1
# Frame Number=1404 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=1405 Number of Objects=16 Vehicle_count=15 Person_count=1
# Frame Number=1406 Number of Objects=18 Vehicle_count=16 Person_count=2
# Frame Number=1407 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=1408 Number of Objects=15 Vehicle_count=14 Person_count=1
# Frame Number=1409 Number of Objects=16 Vehicle_count=14 Person_count=2
# Frame Number=1410 Number of Objects=17 Vehicle_count=16 Person_count=1
# Frame Number=1411 Number of Objects=18 Vehicle_count=16 Person_count=2
# Frame Number=1412 Number of Objects=17 Vehicle_count=15 Person_count=2
# Frame Number=1413 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1414 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1415 Number of Objects=10 Vehicle_count=7 Person_count=3
# Frame Number=1416 Number of Objects=11 Vehicle_count=8 Person_count=3
# Frame Number=1417 Number of Objects=9 Vehicle_count=7 Person_count=2
# Frame Number=1418 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=1419 Number of Objects=12 Vehicle_count=9 Person_count=3
# Frame Number=1420 Number of Objects=11 Vehicle_count=8 Person_count=3
# Frame Number=1421 Number of Objects=11 Vehicle_count=8 Person_count=3
# Frame Number=1422 Number of Objects=10 Vehicle_count=8 Person_count=2
# Frame Number=1423 Number of Objects=9 Vehicle_count=7 Person_count=2
# Frame Number=1424 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=1425 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=1426 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=1427 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=1428 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=1429 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1430 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=1431 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1432 Number of Objects=11 Vehicle_count=9 Person_count=2
# Frame Number=1433 Number of Objects=12 Vehicle_count=10 Person_count=2
# Frame Number=1434 Number of Objects=15 Vehicle_count=12 Person_count=3
# Frame Number=1435 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1436 Number of Objects=15 Vehicle_count=13 Person_count=2
# Frame Number=1437 Number of Objects=14 Vehicle_count=12 Person_count=2
# Frame Number=1438 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1439 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1440 Number of Objects=13 Vehicle_count=11 Person_count=2
# Frame Number=1441 Number of Objects=0 Vehicle_count=0 Person_count=0
# End-of-stream

# %% [markdown]
# # 1.2 Configure an Object Detection Model

# %% [markdown]
# The sample application shows counts for two types of objects: `Vehicle` and `Person`.  This is specified in the display output line (line 101):
#
# ```python
# py_nvosd_text_params.display_text =
#     "Frame Number={} Number of Objects={} Vehicle_count={} Person_count={}" \
#     .format(frame_number,
#             num_rects,
#             obj_counter[PGIE_CLASS_ID_VEHICLE],
#             obj_counter[PGIE_CLASS_ID_PERSON])
# ```
#
# However, the model used can actually detect four types of objects as revealed in the class ID assignments in the application script:
#
# ```python
# PGIE_CLASS_ID_VEHICLE = 0
# PGIE_CLASS_ID_BICYCLE = 1
# PGIE_CLASS_ID_PERSON = 2
# PGIE_CLASS_ID_ROADSIGN = 3
# ```
#
# If you watch the application stream carefully, there is a bicycle in the early frames.  It is detected and boxed briefly.  The same is true for road signs.  You can see this when using a different stream such as the `sample_qHD.h264` sample.

# %% [markdown]
# ## 1.2.1 `Gst-nvinfer` Configuration File
# The classification labels (the types of objects detected) are specific to the model used for the inference, which in this case is a sample model provided with the DeepStream SDK.  The `Gst-nvinfer` plugin employs a configuration file to specify the model and various properties. Open the configuration file for the app we are using at [deepstream/sources/deepstream_python_apps/apps/deepstream-test1-rtsp-out/dstest1_pgie_config.txt](deepstream/sources/deepstream_python_apps/apps/deepstream-test1-rtsp-out/dstest1_pgie_config.txt).  The `Gst-nvinfer` configuration file uses a key file format, with details on key names found in the [DeepStream Developer Guide](https://docs.nvidia.com/metropolis/deepstream/dev-guide/text/DS_plugin_gst-nvinfer.html#gst-nvinfer-file-configuration-specifications).
# - The **\[property\]** group configures the general behavior of the plugin. It is the only mandatory group.
# - The **\[class-attrs-all\]** group configures detection parameters for all classes.
# - The **\[class-attrs-\<class-id\>\]** group configures detection parameters for a class specified by \<class-id\>. For example, the \[class-attrs-2\] group configures detection parameters for class ID 2\. This type of group has the same keys as \[class-attrs-all\].
#
# For the most part, we can use the default values.  There are a few improvements we can make, however.

# %% [markdown]
# ### [property] : `model-engine-file`
# During the previous test run, you may have noticed that an error was produced:
#
# ```C
# ERROR: Deserialize engine failed because file path: /opt/nvidia/deepstream/deepstream-6.0/sources/deepstream_python_apps/apps/deepstream-test1-rtsp-out/../../../../samples/models/Primary_Detector/resnet10.caffemodel_b1_gpu0_int8.engine open error
# ```
#
# This error indicates that the TensoRT optimized model engine is not present.  Since it is not there, an attempt is made to build it.  There is a problem though...
#
# ```c
# WARNING: INT8 not supported by platform. Trying FP16 mode.
# ```
#
# The Jetson Nano does not support INT8 mode, so an FP16 engine is built instead.  When it's complete, inference is run on the file stream and we see the result in the RTSP output.  Along the way, there is a notice that the engine was created and where it resides:
#
# ```c
# serialize cuda engine to file: /opt/nvidia/deepstream/deepstream-6.0/samples/models/Primary_Detector/resnet10.caffemodel_b1_gpu0_fp16.engine successfully
# ```
#
# This engine now exists and can be reused, which saves a lot of time if you want to run the app again.  Unfortunately, since the configuration file specifies a different engine (the INT8 engine), the engine will be rebuilt anyway, which will cause an unnecessary delay!
#
# To reuse the engine just built, the configuration property, `model-engine-file`, must be set to the correct path.  The next cell provides a quick substitution fix.  Go ahead and execute it now:

# %%
# Change the engine to fp16
# !sed -i 's/_int8.engine/_fp16.engine/g' $PYTHON_APPS/deepstream-test1-rtsp-out/dstest1_pgie_config.txt

# %% [markdown]
# ### [class-attrs-\<all or class-id\>] : `pre-cluster-threshold`
# The number of classes and the ordered `labels.txt` file path are specified in the \[property\] group along with the model engine. To configure which of these labels the object detector actually recognizes, we can change keys in the \[class-attrs-all\] and \[class-attrs-\<class-id\>\] groups.  The initial sample configuration file includes the following:
# ```c
# [class-attrs-all]
# pre-cluster-threshold=0.2
# eps=0.2
# group-threshold=1
# ```
#
# The `pre-cluster-threshold=0.2` key sets the detection confidence score. This tells us that all objects with a 20% confidence score or better will be marked as detected. If the threshold is greater than 1.0, then no objects will be detected, because a confidence of more than 100% would be required which is impossible!
#
# This "all" grouping is not granular enough if we only want to detect a subset of the objects possible, or if we wish to use a different confidence level with different objects.  For example, we might choose to detect only vehicles, or to identify people with a different confidence level than road signs.  To specify a threshold for the four individual objects available in this model, we can add a specific group to the config file for each class:
#
# - \[class-attrs-0\] for vehicles
# - \[class-attrs-1\] for bicycles
# - \[class-attrs-2\] for persons
# - \[class-attrs-3\] for road signs
#
# Then, in each group, we can specify the threshold value.  This can be used to determine object detection for each of the four object categories individually.

# %% [markdown]
# ## 1.2.2 Exercise: Detect Only Two Object Types
# Create a new app based on `deepstream-test1-rtsp_out` that detects *only* cars and bicycles. Begin by copying the existing app to a new workspace.

# %%
# Set up the workspace for my new Python apps
MY_APPS = '/opt/nvidia/deepstream/deepstream/sources/deepstream_python_apps/my_apps'
# !cp -r $PYTHON_APPS/common $MY_APPS/

# %%
# Create a new app located at my_apps/dst1-two-objects 
#      based on deepstream-test1-rtsp_out
# !mkdir -p $MY_APPS/dst1-two-objects
# !cp -rfv $PYTHON_APPS/deepstream-test1-rtsp-out/* $MY_APPS/dst1-two-objects/

# %% [markdown]
# Using what you just learned, modify the [configuration file](deepstream/sources/deepstream_python_apps/my_apps/dst1-two-objects/dstest1_pgie_config.txt) in your new app to detect *only* cars and bicycles.  You will need to add *class-specific groups* for each of the four classes to the end of your configuration file.<br>
# Class-specific example:
#    ```
#     # Per class configuration
#     # car
#     [class-attrs-0]
#     pre-cluster-threshold=0.2
#    ```
# Then, run the app to see if it worked!

# %%
# Run the app
# !cd $MY_APPS/dst1-two-objects \
    && python3 deepstream_test1_rtsp_out.py -i $STREAMS/sample_720p.h264

# %% [markdown]
# #### How did you do?
# If you see something like this image, with only bicycles and cars detected you did it!  If not, keep trying or take a peek at the [solution](solutions/ex1.2.2_DetectTwo/ex1.2.2_dstest1_pgie_config.txt) config file in the solutions directory. If you aren't satisfied with the detection of the bicycle, you can experiment with the confidence threshold value. <br>

# %% [markdown]
# <img src="../../images/01_bikes_and_cars.png">

# %% [markdown]
# <h2 style="color:green;">Congratulations!</h2>
#
# You've run your first DeepStream sample app and created a new DeepStream app to detect different objects in a scene.<br>
# Move on to [2.0 Analysis with Metadata](02_Metadata.ipynb) to expand your video analysis.

# %% [markdown]
# <center><img src="images/DLI Header.png" alt="Header" width="400"></center>
